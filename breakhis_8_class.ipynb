# %% [markdown]
# # **Data Processing**

# %%
#@title Requirements

import tensorflow as tf
import os
# Out:
# 2024-03-28 20:22:33.136702: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-28 20:22:33.136806: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-28 20:22:33.366918: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-28 20:22:33.858688: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-28 20:22:40.034166: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
#@title Data Cleansing

import cv2
import imghdr
from matplotlib import pyplot as plt

data_dir = ['/home/cmater/Desktop/Akash_MCSE/Surya/breakhis-dataset-expanded']

# %%
#@title Creating Data Pipeline
import numpy as np

data = tf.keras.utils.image_dataset_from_directory('/home/cmater/Desktop/Akash_MCSE/Surya/breakhis-dataset-expanded', batch_size=16, shuffle=True)     # Building data pipeline

data_iterator = data.as_numpy_iterator()        # Helps in accessing data pipeline
batch = data_iterator.next()            # Accessing data pipeline
print("Batch classes: ", batch[1])
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])
# Out:
# Found 7909 files belonging to 8 classes.
# 2024-03-28 20:23:43.836967: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-28 20:23:45.525475: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-28 20:23:45.532490: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-28 20:23:45.588711: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-28 20:23:45.589166: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-28 20:23:45.589514: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-28 20:23:45.798468: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-28 20:23:45.798671: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-28 20:23:45.798865: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-28 20:23:45.798967: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7268 MB memory:  -> device: 0, name: Quadro M4000, pci bus id: 0000:02:00.0, compute capability: 5.2
# 2024-03-28 20:23:47.555641: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# Batch classes:  [5 1 7 5 2 0 5 2 2 1 1 6 1 4 6 1]

# %%
# Access class names
class_names = data.class_names

# Print class names and their corresponding labels
for label, class_name in enumerate(class_names):
    print(f"Label {label}: {class_name}")
# Out:
# Label 0: adenosis
# Label 1: ductal_carcinoma
# Label 2: fibroadenoma
# Label 3: lobular_carcinoma
# Label 4: mucinous_carcinoma
# Label 5: papillary_carcinoma
# Label 6: phyllodes_tumor
# Label 7: tubular_adenoma

# %%
''' Scaling Data '''
# Scaling Data
data = data.map(lambda x,y: (x/255, y))
data.as_numpy_iterator().next()[0].max()


''' Splitting Data '''
train_size = int(len(data)*.7)
val_size = int(len(data)*.1)
test_size = int(len(data)*.2)

train = data.take(train_size)
val = data.take(val_size)
test = data.take(test_size)

print(train_size, "+", test_size, "+", val_size, "=", len(data))
# Out:
# 346 + 99 + 49 = 495

# %%
#@title Assigning weights to classes
from sklearn.utils.class_weight import compute_class_weight
from tqdm import tqdm

# images = []
labels = []
# data = []
for batch in tqdm(train.as_numpy_iterator()):
    X1, y1 = batch
    labels.extend(list(y1))

labels = np.array(labels)
print(labels)

# Calculate class weights using scikit-learn's compute_class_weight function
class_weights = compute_class_weight(class_weight = 'balanced', classes = np.unique(labels), y = labels)
class_weights = dict(zip(np.unique(labels), class_weights))
# Out:
# 346it [01:14,  4.65it/s]
# [3 2 0 ... 0 1 2]

# %% [markdown]
# # **Deep Learning Models Creation, Training, Evaluating, Saving, Performance Graph etc.**

# %%
#@title Wave Conversion Layer

from tensorflow.keras.layers import Layer
from tensorflow.keras.layers import Concatenate, Flatten
import numpy as np
import math
from itertools import combinations

class WaveConvertLayer(Layer):
    def __init__(self, top=None, mode='pearson', alpha=0.5, beta=0.4, **kwargs):
        super(WaveConvertLayer, self).__init__(**kwargs)
        self.top = top
        self.mode = mode
        self.alpha = alpha
        self.beta = beta

    def pearson_correlation_coefficient(self, tup):
        x = tup[0]
        y = tup[1]
        x_flat = tf.reshape(x, [-1, tf.shape(x)[1] * tf.shape(x)[2] * tf.shape(x)[3]])
        y_flat = tf.reshape(y, [-1, tf.shape(y)[1] * tf.shape(y)[2] * tf.shape(y)[3]])

        # Cosine Similarity
        dot_product = tf.reduce_sum(tf.multiply(x_flat, y_flat), axis=-1, keepdims=True)
        norm_x = tf.norm(x_flat, axis=-1, keepdims=True)
        norm_y = tf.norm(y_flat, axis=-1, keepdims=True)
        cos_similarity = dot_product / (norm_x * norm_y)

        # Pearson Correlation Coefficient
        x_mean = tf.reduce_mean(x_flat, axis=-1, keepdims=True)
        y_mean = tf.reduce_mean(y_flat, axis=-1, keepdims=True)
        X = x_flat - x_mean
        Y = y_flat - y_mean
        pr_similarity = tf.reduce_sum((X*Y), axis=-1, keepdims=True)/tf.sqrt(tf.reduce_sum((X**2), axis=-1, keepdims=True) * tf.reduce_sum((Y**2), axis=-1, keepdims=True))

        # Fused Similarity
        similarity = ((self.alpha * pr_similarity) + cos_similarity)/2.0
        return similarity

    def spearman_rank_correlation(self, tup):
        x = tup[0]
        y = tup[1]
        x_flat = tf.reshape(x, [-1, tf.shape(x)[1] * tf.shape(x)[2] * tf.shape(x)[3]])
        y_flat = tf.reshape(y, [-1, tf.shape(y)[1] * tf.shape(y)[2] * tf.shape(y)[3]])

        # Cosine Similarity
        dot_product = tf.reduce_sum(tf.multiply(x_flat, y_flat), axis=-1, keepdims=True)
        norm_x = tf.norm(x_flat, axis=-1, keepdims=True)
        norm_y = tf.norm(y_flat, axis=-1, keepdims=True)
        cos_similarity = dot_product / (norm_x * norm_y)

        # Spearman Rank Correlation
        d = x_flat - y_flat
        n = x_flat.shape[-1]
        rho = 1 - ((6 * tf.reduce_sum((d**2), axis=-1, keepdims=True))/(n * (n**2 - 1)))

        # Fused Similarity
        similarity = ((self.alpha * rho) + cos_similarity)/2.0
        return similarity

    def similarity_compute(self, mean, *argv):
        L = len(argv)
        arg_shape = argv[0].shape

        similarities = []
        for i, arg in enumerate(argv):
            if self.mode == "pearson":
                sim = self.pearson_correlation_coefficient((mean, arg))
            elif self.mode == "spearman":
                sim = self.spearman_rank_correlation((mean, arg))

            similarities.append(sim)

        similarities = Concatenate(axis=-1)(similarities)
        argv = Concatenate(axis=-1)(argv)
        a = 3.1; h = 1.065; c = 1.1; k = 0.1;
        score = tf.math.exp(a * (similarities - h)) * c + k
        score_reshaped = tf.expand_dims(score, axis=1)
        score_reshaped = tf.expand_dims(score_reshaped, axis=1)
        score_reshaped = tf.tile(score_reshaped, [1, argv.shape[-3], argv.shape[-2], 1])
        filtered_map = argv * score_reshaped

        return filtered_map


    def call(self, inputs):
        l = []
        for i in range(inputs.shape[-1]):
            l.append(tf.expand_dims(inputs[:, :, :, i], axis=-1))

        mean = tf.reduce_mean(inputs, axis=-1, keepdims=True)
        predictions = self.similarity_compute(mean, *l)

        l = []
        for i in range(predictions.shape[-1]):
            l.append(tf.expand_dims(predictions[:, :, :, i], axis=-1))

        flattened_outp = [Flatten()(i) for i in l]
        predictions = tf.stack(flattened_outp, axis=-1)

        return predictions

# %%
''' Deep Model '''
#@title MobileNetV2

import tensorflow as tf
import keras.backend as K
from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Layer, Conv2D, MaxPool2D, Dense, Flatten, Dropout, AveragePooling2D, Concatenate, Conv2DTranspose, GlobalAveragePooling2D, BatchNormalization, ReLU, Reshape, Resizing, Add, SeparableConv2D, MultiHeadAttention, UpSampling2D, LayerNormalization, ZeroPadding2D, DepthwiseConv2D, Activation
from tensorflow.keras.layers import LSTM, Bidirectional, Conv1D, MaxPool1D
from tensorflow.keras.applications import Xception, MobileNetV2, DenseNet201, ResNet50
from tensorflow.keras.models import Sequential
from tensorflow.keras.metrics import Recall, Precision, Accuracy
import math

def waveparse(input_x, filters, a, count):
    x = Conv1D(filters[0], 4, strides=2, padding='same', activation='relu', name='conv1d1'+count)(input_x)
    x = MaxPool1D(filters[1], padding='valid', name='pool1D'+count)(x)
    x = Conv1D(filters[3], 4, strides=2, padding='same', activation='relu', name='conv1d2'+count)(x)
    x = Reshape((a, a, x.shape[-1]))(x)
    return x

def mod(img_shape, n_classes):
    input_x = Input(shape=img_shape, name='input_1')

    # Conv1 block
    x = Conv2D(32, (3, 3), strides=(2, 2), padding='same', use_bias=False, name='Conv1')(input_x)
    x = BatchNormalization(name='bn_Conv1')(x)
    x = ReLU(name='Conv1_relu')(x)

    # Expanded Conv block
    x = DepthwiseConv2D((3, 3), strides=(1, 1), padding='same', use_bias=False, name='expanded_conv_depthwise')(x)
    x = BatchNormalization(name='expanded_conv_depthwise_BN')(x)
    x = ReLU(name='expanded_conv_depthwise_relu')(x)
    x = Conv2D(16, (1, 1), strides=(1, 1), padding='same', use_bias=False, name='expanded_conv_project')(x)
    x = BatchNormalization(name='expanded_conv_project_BN')(x)

    # block_1
    x = Conv2D(96, (1, 1), strides=(1, 1), padding='same', name='block_1_expand')(x)
    x = BatchNormalization(name='block_1_expand_BN')(x)
    x = ReLU(name='block_1_expand_relu')(x)
    x = ZeroPadding2D(padding=((1, 0), (1, 0)), name='block_1_pad')(x)
    x = DepthwiseConv2D((3, 3), strides=(2, 2), padding='valid', use_bias=False, name='block_1_depthwise')(x)
    x = BatchNormalization(name='block_1_depthwise_BN')(x)
    x = ReLU(name='block_1_depthwise_relu')(x)
    x = Conv2D(24, (1, 1), strides=(1, 1), padding='same', use_bias=False, name='block_1_project')(x)
    x_1 = BatchNormalization(name='block_1_project_BN')(x)

    # block_2
    x = Conv2D(144, (1, 1), strides=(1, 1), padding='same', use_bias=False, name='block_2_expand')(x_1)
    x = BatchNormalization(name='block_2_expand_BN')(x)
    x = ReLU(name='block_2_expand_relu')(x)
    x = DepthwiseConv2D((3, 3), strides=(1, 1), padding='same', use_bias=False, name='block_2_depthwise')(x)
    x = BatchNormalization(name='block_2_depthwise_BN')(x)
    x = ReLU(name='block_2_depthwise_relu')(x)
    x = Conv2D(24, (1, 1), strides=(1, 1), padding='same', use_bias=False, name='block_2_project')(x)
    x = BatchNormalization(name='block_2_project_BN')(x)
    x = Add(name='block_2_add')([x_1, x])
    x_00 = WaveConvertLayer(top=math.ceil(x.shape[-1]*(95.0/100.0)), mode="pearson", alpha=0.5, beta=0.4, name="pearson_correlation_coef")(x)

    # block_3
    x = Conv2D(144, (1, 1), strides=(1, 1), padding='same', use_bias=False, name='block_3_expand')(x)
    x = BatchNormalization(name='block_3_expand_BN')(x)
    x = ReLU(name='block_3_expand_relu')(x)
    x = ZeroPadding2D(padding=((1, 0), (1, 0)), name='block_3_pad')(x)
    x = DepthwiseConv2D((3, 3), strides=(2, 2), padding='valid', use_bias=False, name='block_3_depthwise')(x)
    x = BatchNormalization(name='block_3_depthwise_BN')(x)
    x = ReLU(name='block_3_depthwise_relu')(x)
    x = Conv2D(32, (1, 1), strides=(1, 1), padding='same', use_bias=False, name='block_3_project')(x)
    x_3 = BatchNormalization(name='block_3_project_BN')(x)

    # block_4
    x = Conv2D(192, (1, 1), strides=(1, 1), padding='same', use_bias=False, name='block_4_expand')(x_3)
    x = BatchNormalization(name='block_4_expand_BN')(x)
    x = ReLU(name='block_4_expand_relu')(x)
    x = DepthwiseConv2D((3, 3), strides=(1, 1), padding='same', use_bias=False, name='block_4_depthwise')(x)
    x = BatchNormalization(name='block_4_depthwise_BN')(x)
    x = ReLU(name='block_4_depthwise_relu')(x)
    x = Conv2D(32, (1, 1), strides=(1, 1), padding='same', use_bias=False, name='block_4_project')(x)
    x = BatchNormalization(name='block_4_project_BN')(x)
    x_4 = Add(name='block_4_add')([x_3, x])
    x_20 = WaveConvertLayer(top=math.ceil(x_4.shape[-1]*(97.0/100.0)), mode="spearman", alpha=0.5, beta=0.5, name="spearman_rank_corre")(x_4)

    # block_5
    x = Conv2D(192, (1, 1), strides=(1, 1), padding='same', use_bias=False, name='block_5_expand')(x_4)
    x = BatchNormalization(name='block_5_expand_BN')(x)
    x = ReLU(name='block_5_expand_relu')(x)
    x = DepthwiseConv2D((3, 3), strides=(1, 1), padding='same', use_bias=False, name='block_5_depthwise')(x)
    x = BatchNormalization(name='block_5_depthwise_BN')(x)
    x = ReLU(name='block_5_depthwise_relu')(x)
    x = Conv2D(32, (1, 1), strides=(1, 1), padding='same', use_bias=False, name='block_5_project')(x)
    x = BatchNormalization(name='block_5_project_BN')(x)
    x = Add(name='block_5_add')([x_4, x])

    # block_6
    x = Conv2D(192, (1, 1), strides=(1, 1), padding='same', use_bias=False, name='block_6_expand')(x)
    x = BatchNormalization(name='block_6_expand_BN')(x)
    x = ReLU(name='block_6_expand_relu')(x)
    x = ZeroPadding2D(padding=((1, 0), (1, 0)), name='block_6_pad')(x)
    x = DepthwiseConv2D((3, 3), strides=(2, 2), padding='valid', use_bias=False, name='block_6_depthwise')(x)
    x = BatchNormalization(name='block_6_depthwise_BN')(x)
    x = ReLU(name='block_6_depthwise_relu')(x)
    x = Conv2D(64, (1, 1), strides=(1, 1), padding='same', use_bias=False, name='block_6_project')(x)
    x_6 = BatchNormalization(name='block_6_project_BN')(x)

    # block_7
    x = Conv2D(384, (1, 1), strides=(1, 1), padding='same', use_bias=False, name='block_7_expand')(x_6)
    x = BatchNormalization(name='block_7_expand_BN')(x)
    x = ReLU(name='block_7_expand_relu')(x)
    x = DepthwiseConv2D((3, 3), strides=(1, 1), padding='same', use_bias=False, name='block_7_depthwise')(x)
    x = BatchNormalization(name='block_7_depthwise_BN')(x)
    x = ReLU(name='block_7_depthwise_relu')(x)
    x = Conv2D(64, (1, 1), strides=(1, 1), padding='same', use_bias=False, name='block_7_project')(x)
    x = BatchNormalization(name='block_7_project_BN')(x)
    x_7 = Add(name='block_7_add')([x_6, x])

    # block_8
    x = Conv2D(384, (1, 1), strides=(1, 1), padding='same', use_bias=False, name='block_8_expand')(x_7)
    x = BatchNormalization(name='block_8_expand_BN')(x)
    x = ReLU(name='block_8_expand_relu')(x)
    x = DepthwiseConv2D((3, 3), strides=(1, 1), padding='same', use_bias=False, name='block_8_depthwise')(x)
    x = BatchNormalization(name='block_8_depthwise_BN')(x)
    x = ReLU(name='block_8_depthwise_relu')(x)
    x = Conv2D(64, (1, 1), strides=(1, 1), padding='same', use_bias=False, name='block_8_project')(x)
    x = BatchNormalization(name='block_8_project_BN')(x)
    x_8 = Add(name='block_8_add')([x_7, x])

    # block_9
    x = Conv2D(384, (1, 1), strides=(1, 1), padding='same', use_bias=False, name='block_9_expand')(x_8)
    x = BatchNormalization(name='block_9_expand_BN')(x)
    x = ReLU(name='block_9_expand_relu')(x)
    x = DepthwiseConv2D((3, 3), strides=(1, 1), padding='same', use_bias=False, name='block_9_depthwise')(x)
    x = BatchNormalization(name='block_9_depthwise_BN')(x)
    x = ReLU(name='block_9_depthwise_relu')(x)
    x = Conv2D(64, (1, 1), strides=(1, 1), padding='same', use_bias=False, name='block_9_project')(x)
    x = BatchNormalization(name='block_9_project_BN')(x)
    x = Add(name='block_9_add')([x_8, x])
    x_20 = Conv1D(64, 4, strides=2, padding='same', activation='relu', name='conv1d2')(x_20)
    x_20 = Conv1D(64, 4, strides=2, padding='same', activation='relu', name='conv1d22')(x_20)
    x_20 = Reshape((x.shape[-2], x.shape[-2], x.shape[-1]))(x_20)
    x = x * x_20

    # block_10
    x = Conv2D(384, (1, 1), strides=(1, 1), padding='same', use_bias=False, name='block_10_expand')(x)
    x = BatchNormalization(name='block_10_expand_BN')(x)
    x = ReLU(name='block_10_expand_relu')(x)
    x = DepthwiseConv2D((3, 3), strides=(1, 1), padding='same', use_bias=False, name='block_10_depthwise')(x)
    x = BatchNormalization(name='block_10_depthwise_BN')(x)
    x = ReLU(name='block_10_depthwise_relu')(x)
    x = Conv2D(96, (1, 1), strides=(1, 1), padding='same', use_bias=False, name='block_10_project')(x)
    x_10 = BatchNormalization(name='block_10_project_BN')(x)

    # block_11
    x = Conv2D(576, (1, 1), padding='same', use_bias=False, name='block_11_expand')(x_10)
    x = BatchNormalization(name='block_11_expand_BN')(x)
    x = ReLU(name='block_11_expand_relu')(x)
    x = DepthwiseConv2D((3, 3), padding='same', use_bias=False, name='block_11_depthwise')(x)
    x = BatchNormalization(name='block_11_depthwise_BN')(x)
    x = ReLU(name='block_11_depthwise_relu')(x)
    x = Conv2D(96, (1, 1), padding='same', use_bias=False, name='block_11_project')(x)
    x = BatchNormalization(name='block_11_project_BN')(x)
    x_11 = Add(name='block_11_add')([x_10, x])
    x_00 = waveparse(x_00, [64, 4, 64, 96], x_11.shape[-2], "_1")
    x_11 = x_11 * x_00

    # block_12
    x = Conv2D(576, (1, 1), padding='same', use_bias=False, name='block_12_expand')(x_11)
    x = BatchNormalization(name='block_12_expand_BN')(x)
    x = ReLU(name='block_12_expand_relu')(x)
    x = DepthwiseConv2D((3, 3), padding='same', use_bias=False, name='block_12_depthwise')(x)
    x = BatchNormalization(name='block_12_depthwise_BN')(x)
    x = ReLU(name='block_12_depthwise_relu')(x)
    x = Conv2D(96, (1, 1), padding='same', use_bias=False, name='block_12_project')(x)
    x = BatchNormalization(name='block_12_project_BN')(x)
    x = Add(name='block_12_add')([x_11, x])

    # block_13
    x = Conv2D(576, (1, 1), padding='same', use_bias=False, name='block_13_expand')(x)
    x = BatchNormalization(name='block_13_expand_BN')(x)
    x = ReLU(name='block_13_expand_relu')(x)
    x = tf.keras.layers.ZeroPadding2D(padding=((0, 1), (0, 1)), name='block_13_pad')(x)
    x = DepthwiseConv2D((3, 3), strides=(2, 2), padding='valid', use_bias=False, name='block_13_depthwise')(x)
    x = BatchNormalization(name='block_13_depthwise_BN')(x)
    x = ReLU(name='block_13_depthwise_relu')(x)
    x = Conv2D(160, (1, 1), padding='same', use_bias=False, name='block_13_project')(x)
    x_13 = BatchNormalization(name='block_13_project_BN')(x)

    # block_14
    x = Conv2D(960, (1, 1), padding='same', use_bias=False, name='block_14_expand')(x_13)
    x = BatchNormalization(name='block_14_expand_BN')(x)
    x = ReLU(name='block_14_expand_relu')(x)
    x = DepthwiseConv2D((3, 3), padding='same', use_bias=False, name='block_14_depthwise')(x)
    x = BatchNormalization(name='block_14_depthwise_BN')(x)
    x = ReLU(name='block_14_depthwise_relu')(x)
    x = Conv2D(160, (1, 1), padding='same', use_bias=False, name='block_14_project')(x)
    x = BatchNormalization(name='block_14_project_BN')(x)
    x_14 = Add(name='block_14_add')([x_13, x])

    # block_15
    x = Conv2D(960, (1, 1), padding='same', use_bias=False, name='block_15_expand')(x_14)
    x = BatchNormalization(name='block_15_expand_BN')(x)
    x = ReLU(name='block_15_expand_relu')(x)
    x = DepthwiseConv2D((3, 3), padding='same', use_bias=False, name='block_15_depthwise')(x)
    x = BatchNormalization(name='block_15_depthwise_BN')(x)
    x = ReLU(name='block_15_depthwise_relu')(x)
    x = Conv2D(160, (1, 1), padding='same', use_bias=False, name='block_15_project')(x)
    x = BatchNormalization(name='block_15_project_BN')(x)
    x = Add(name='block_15_add')([x_14, x])

    # block_16
    x = Conv2D(960, (1, 1), padding='same', use_bias=False, name='block_16_expand')(x)
    x = BatchNormalization(name='block_16_expand_BN')(x)
    x = ReLU(name='block_16_expand_relu')(x)
    x = DepthwiseConv2D((3, 3), padding='same', use_bias=False, name='block_16_depthwise')(x)
    x = BatchNormalization(name='block_16_depthwise_BN')(x)
    x = ReLU(name='block_16_depthwise_relu')(x)
    x = Conv2D(320, (1, 1), padding='same', use_bias=False, name='block_16_project')(x)
    x = BatchNormalization(name='block_16_project_BN')(x)

    # Final
    x = Conv2D(1280, (1, 1), padding='same', use_bias=False, name='Conv_1')(x)
    x = BatchNormalization(name='Conv_1_bn')(x)
    x = ReLU(name='out_relu')(x)

    # Outputs
    x = GlobalAveragePooling2D()(x)
    x = Dropout(rate = 0.2)(x)
    x = Dense(n_classes, activation='softmax')(x)

    model = Model(inputs=input_x, outputs=x, name="MobileNetV2CRNN")
    return model

input_shape = (256, 256, 3)
n_classes = 8


model = mod(input_shape, n_classes)
model.compile(tf.keras.optimizers.Adam(learning_rate=0.00001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "MobileNetV2CRNN"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  Conv1 (Conv2D)              (None, 128, 128, 32)         864       ['input_1[0][0]']
#
#  bn_Conv1 (BatchNormalizati  (None, 128, 128, 32)         128       ['Conv1[0][0]']
#  on)
#
#  Conv1_relu (ReLU)           (None, 128, 128, 32)         0         ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (D  (None, 128, 128, 32)         288       ['Conv1_relu[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv_depthwise_BN  (None, 128, 128, 32)         128       ['expanded_conv_depthwise[0][0
#   (BatchNormalization)                                              ]']
#
#  expanded_conv_depthwise_re  (None, 128, 128, 32)         0         ['expanded_conv_depthwise_BN[0
#  lu (ReLU)                                                          ][0]']
#
#  expanded_conv_project (Con  (None, 128, 128, 16)         512       ['expanded_conv_depthwise_relu
#  v2D)                                                               [0][0]']
#
#  expanded_conv_project_BN (  (None, 128, 128, 16)         64        ['expanded_conv_project[0][0]'
#  BatchNormalization)                                                ]
#
#  block_1_expand (Conv2D)     (None, 128, 128, 96)         1632      ['expanded_conv_project_BN[0][
#                                                                     0]']
#
#  block_1_expand_BN (BatchNo  (None, 128, 128, 96)         384       ['block_1_expand[0][0]']
#  rmalization)
#
#  block_1_expand_relu (ReLU)  (None, 128, 128, 96)         0         ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D  (None, 129, 129, 96)         0         ['block_1_expand_relu[0][0]']
#  )
#
#  block_1_depthwise (Depthwi  (None, 64, 64, 96)           864       ['block_1_pad[0][0]']
#  seConv2D)
#
#  block_1_depthwise_BN (Batc  (None, 64, 64, 96)           384       ['block_1_depthwise[0][0]']
#  hNormalization)
#
#  block_1_depthwise_relu (Re  (None, 64, 64, 96)           0         ['block_1_depthwise_BN[0][0]']
#  LU)
#
#  block_1_project (Conv2D)    (None, 64, 64, 24)           2304      ['block_1_depthwise_relu[0][0]
#                                                                     ']
#
#  block_1_project_BN (BatchN  (None, 64, 64, 24)           96        ['block_1_project[0][0]']
#  ormalization)
#
#  block_2_expand (Conv2D)     (None, 64, 64, 144)          3456      ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNo  (None, 64, 64, 144)          576       ['block_2_expand[0][0]']
#  rmalization)
#
#  block_2_expand_relu (ReLU)  (None, 64, 64, 144)          0         ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (Depthwi  (None, 64, 64, 144)          1296      ['block_2_expand_relu[0][0]']
#  seConv2D)
#
#  block_2_depthwise_BN (Batc  (None, 64, 64, 144)          576       ['block_2_depthwise[0][0]']
#  hNormalization)
#
#  block_2_depthwise_relu (Re  (None, 64, 64, 144)          0         ['block_2_depthwise_BN[0][0]']
#  LU)
#
#  block_2_project (Conv2D)    (None, 64, 64, 24)           3456      ['block_2_depthwise_relu[0][0]
#                                                                     ']
#
#  block_2_project_BN (BatchN  (None, 64, 64, 24)           96        ['block_2_project[0][0]']
#  ormalization)
#
#  block_2_add (Add)           (None, 64, 64, 24)           0         ['block_1_project_BN[0][0]',
#                                                                      'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)     (None, 64, 64, 144)          3456      ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNo  (None, 64, 64, 144)          576       ['block_3_expand[0][0]']
#  rmalization)
#
#  block_3_expand_relu (ReLU)  (None, 64, 64, 144)          0         ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D  (None, 65, 65, 144)          0         ['block_3_expand_relu[0][0]']
#  )
#
#  block_3_depthwise (Depthwi  (None, 32, 32, 144)          1296      ['block_3_pad[0][0]']
#  seConv2D)
#
#  block_3_depthwise_BN (Batc  (None, 32, 32, 144)          576       ['block_3_depthwise[0][0]']
#  hNormalization)
#
#  block_3_depthwise_relu (Re  (None, 32, 32, 144)          0         ['block_3_depthwise_BN[0][0]']
#  LU)
#
#  block_3_project (Conv2D)    (None, 32, 32, 32)           4608      ['block_3_depthwise_relu[0][0]
#                                                                     ']
#
#  block_3_project_BN (BatchN  (None, 32, 32, 32)           128       ['block_3_project[0][0]']
#  ormalization)
#
#  block_4_expand (Conv2D)     (None, 32, 32, 192)          6144      ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNo  (None, 32, 32, 192)          768       ['block_4_expand[0][0]']
#  rmalization)
#
#  block_4_expand_relu (ReLU)  (None, 32, 32, 192)          0         ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (Depthwi  (None, 32, 32, 192)          1728      ['block_4_expand_relu[0][0]']
#  seConv2D)
#
#  block_4_depthwise_BN (Batc  (None, 32, 32, 192)          768       ['block_4_depthwise[0][0]']
#  hNormalization)
#
#  block_4_depthwise_relu (Re  (None, 32, 32, 192)          0         ['block_4_depthwise_BN[0][0]']
#  LU)
#
#  block_4_project (Conv2D)    (None, 32, 32, 32)           6144      ['block_4_depthwise_relu[0][0]
#                                                                     ']
#
#  block_4_project_BN (BatchN  (None, 32, 32, 32)           128       ['block_4_project[0][0]']
#  ormalization)
#
#  block_4_add (Add)           (None, 32, 32, 32)           0         ['block_3_project_BN[0][0]',
#                                                                      'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)     (None, 32, 32, 192)          6144      ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNo  (None, 32, 32, 192)          768       ['block_5_expand[0][0]']
#  rmalization)
#
#  block_5_expand_relu (ReLU)  (None, 32, 32, 192)          0         ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (Depthwi  (None, 32, 32, 192)          1728      ['block_5_expand_relu[0][0]']
#  seConv2D)
#
#  block_5_depthwise_BN (Batc  (None, 32, 32, 192)          768       ['block_5_depthwise[0][0]']
#  hNormalization)
#
#  block_5_depthwise_relu (Re  (None, 32, 32, 192)          0         ['block_5_depthwise_BN[0][0]']
#  LU)
#
#  block_5_project (Conv2D)    (None, 32, 32, 32)           6144      ['block_5_depthwise_relu[0][0]
#                                                                     ']
#
#  block_5_project_BN (BatchN  (None, 32, 32, 32)           128       ['block_5_project[0][0]']
#  ormalization)
#
#  block_5_add (Add)           (None, 32, 32, 32)           0         ['block_4_add[0][0]',
#                                                                      'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)     (None, 32, 32, 192)          6144      ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNo  (None, 32, 32, 192)          768       ['block_6_expand[0][0]']
#  rmalization)
#
#  block_6_expand_relu (ReLU)  (None, 32, 32, 192)          0         ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D  (None, 33, 33, 192)          0         ['block_6_expand_relu[0][0]']
#  )
#
#  block_6_depthwise (Depthwi  (None, 16, 16, 192)          1728      ['block_6_pad[0][0]']
#  seConv2D)
#
#  block_6_depthwise_BN (Batc  (None, 16, 16, 192)          768       ['block_6_depthwise[0][0]']
#  hNormalization)
#
#  block_6_depthwise_relu (Re  (None, 16, 16, 192)          0         ['block_6_depthwise_BN[0][0]']
#  LU)
#
#  block_6_project (Conv2D)    (None, 16, 16, 64)           12288     ['block_6_depthwise_relu[0][0]
#                                                                     ']
#
#  block_6_project_BN (BatchN  (None, 16, 16, 64)           256       ['block_6_project[0][0]']
#  ormalization)
#
#  block_7_expand (Conv2D)     (None, 16, 16, 384)          24576     ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNo  (None, 16, 16, 384)          1536      ['block_7_expand[0][0]']
#  rmalization)
#
#  block_7_expand_relu (ReLU)  (None, 16, 16, 384)          0         ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (Depthwi  (None, 16, 16, 384)          3456      ['block_7_expand_relu[0][0]']
#  seConv2D)
#
#  block_7_depthwise_BN (Batc  (None, 16, 16, 384)          1536      ['block_7_depthwise[0][0]']
#  hNormalization)
#
#  block_7_depthwise_relu (Re  (None, 16, 16, 384)          0         ['block_7_depthwise_BN[0][0]']
#  LU)
#
#  block_7_project (Conv2D)    (None, 16, 16, 64)           24576     ['block_7_depthwise_relu[0][0]
#                                                                     ']
#
#  block_7_project_BN (BatchN  (None, 16, 16, 64)           256       ['block_7_project[0][0]']
#  ormalization)
#
#  block_7_add (Add)           (None, 16, 16, 64)           0         ['block_6_project_BN[0][0]',
#                                                                      'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)     (None, 16, 16, 384)          24576     ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNo  (None, 16, 16, 384)          1536      ['block_8_expand[0][0]']
#  rmalization)
#
#  block_8_expand_relu (ReLU)  (None, 16, 16, 384)          0         ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (Depthwi  (None, 16, 16, 384)          3456      ['block_8_expand_relu[0][0]']
#  seConv2D)
#
#  block_8_depthwise_BN (Batc  (None, 16, 16, 384)          1536      ['block_8_depthwise[0][0]']
#  hNormalization)
#
#  block_8_depthwise_relu (Re  (None, 16, 16, 384)          0         ['block_8_depthwise_BN[0][0]']
#  LU)
#
#  block_8_project (Conv2D)    (None, 16, 16, 64)           24576     ['block_8_depthwise_relu[0][0]
#                                                                     ']
#
#  block_8_project_BN (BatchN  (None, 16, 16, 64)           256       ['block_8_project[0][0]']
#  ormalization)
#
#  block_8_add (Add)           (None, 16, 16, 64)           0         ['block_7_add[0][0]',
#                                                                      'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)     (None, 16, 16, 384)          24576     ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNo  (None, 16, 16, 384)          1536      ['block_9_expand[0][0]']
#  rmalization)
#
#  block_9_expand_relu (ReLU)  (None, 16, 16, 384)          0         ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (Depthwi  (None, 16, 16, 384)          3456      ['block_9_expand_relu[0][0]']
#  seConv2D)
#
#  block_9_depthwise_BN (Batc  (None, 16, 16, 384)          1536      ['block_9_depthwise[0][0]']
#  hNormalization)
#
#  block_9_depthwise_relu (Re  (None, 16, 16, 384)          0         ['block_9_depthwise_BN[0][0]']
#  LU)
#
#  spearman_rank_corre (WaveC  (None, 1024, 32)             0         ['block_4_add[0][0]']
#  onvertLayer)
#
#  block_9_project (Conv2D)    (None, 16, 16, 64)           24576     ['block_9_depthwise_relu[0][0]
#                                                                     ']
#
#  conv1d2 (Conv1D)            (None, 512, 64)              8256      ['spearman_rank_corre[0][0]']
#
#  block_9_project_BN (BatchN  (None, 16, 16, 64)           256       ['block_9_project[0][0]']
#  ormalization)
#
#  conv1d22 (Conv1D)           (None, 256, 64)              16448     ['conv1d2[0][0]']
#
#  block_9_add (Add)           (None, 16, 16, 64)           0         ['block_8_add[0][0]',
#                                                                      'block_9_project_BN[0][0]']
#
#  reshape (Reshape)           (None, 16, 16, 64)           0         ['conv1d22[0][0]']
#
#  tf.math.multiply (TFOpLamb  (None, 16, 16, 64)           0         ['block_9_add[0][0]',
#  da)                                                                 'reshape[0][0]']
#
#  block_10_expand (Conv2D)    (None, 16, 16, 384)          24576     ['tf.math.multiply[0][0]']
#
#  block_10_expand_BN (BatchN  (None, 16, 16, 384)          1536      ['block_10_expand[0][0]']
#  ormalization)
#
#  block_10_expand_relu (ReLU  (None, 16, 16, 384)          0         ['block_10_expand_BN[0][0]']
#  )
#
#  block_10_depthwise (Depthw  (None, 16, 16, 384)          3456      ['block_10_expand_relu[0][0]']
#  iseConv2D)
#
#  block_10_depthwise_BN (Bat  (None, 16, 16, 384)          1536      ['block_10_depthwise[0][0]']
#  chNormalization)
#
#  block_10_depthwise_relu (R  (None, 16, 16, 384)          0         ['block_10_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_10_project (Conv2D)   (None, 16, 16, 96)           36864     ['block_10_depthwise_relu[0][0
#                                                                     ]']
#
#  block_10_project_BN (Batch  (None, 16, 16, 96)           384       ['block_10_project[0][0]']
#  Normalization)
#
#  block_11_expand (Conv2D)    (None, 16, 16, 576)          55296     ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchN  (None, 16, 16, 576)          2304      ['block_11_expand[0][0]']
#  ormalization)
#
#  block_11_expand_relu (ReLU  (None, 16, 16, 576)          0         ['block_11_expand_BN[0][0]']
#  )
#
#  block_11_depthwise (Depthw  (None, 16, 16, 576)          5184      ['block_11_expand_relu[0][0]']
#  iseConv2D)
#
#  block_11_depthwise_BN (Bat  (None, 16, 16, 576)          2304      ['block_11_depthwise[0][0]']
#  chNormalization)
#
#  pearson_correlation_coef (  (None, 4096, 24)             0         ['block_2_add[0][0]']
#  WaveConvertLayer)
#
#  block_11_depthwise_relu (R  (None, 16, 16, 576)          0         ['block_11_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  conv1d1_1 (Conv1D)          (None, 2048, 64)             6208      ['pearson_correlation_coef[0][
#                                                                     0]']
#
#  block_11_project (Conv2D)   (None, 16, 16, 96)           55296     ['block_11_depthwise_relu[0][0
#                                                                     ]']
#
#  pool1D_1 (MaxPooling1D)     (None, 512, 64)              0         ['conv1d1_1[0][0]']
#
#  block_11_project_BN (Batch  (None, 16, 16, 96)           384       ['block_11_project[0][0]']
#  Normalization)
#
#  conv1d2_1 (Conv1D)          (None, 256, 96)              24672     ['pool1D_1[0][0]']
#
#  block_11_add (Add)          (None, 16, 16, 96)           0         ['block_10_project_BN[0][0]',
#                                                                      'block_11_project_BN[0][0]']
#
#  reshape_1 (Reshape)         (None, 16, 16, 96)           0         ['conv1d2_1[0][0]']
#
#  tf.math.multiply_1 (TFOpLa  (None, 16, 16, 96)           0         ['block_11_add[0][0]',
#  mbda)                                                               'reshape_1[0][0]']
#
#  block_12_expand (Conv2D)    (None, 16, 16, 576)          55296     ['tf.math.multiply_1[0][0]']
#
#  block_12_expand_BN (BatchN  (None, 16, 16, 576)          2304      ['block_12_expand[0][0]']
#  ormalization)
#
#  block_12_expand_relu (ReLU  (None, 16, 16, 576)          0         ['block_12_expand_BN[0][0]']
#  )
#
#  block_12_depthwise (Depthw  (None, 16, 16, 576)          5184      ['block_12_expand_relu[0][0]']
#  iseConv2D)
#
#  block_12_depthwise_BN (Bat  (None, 16, 16, 576)          2304      ['block_12_depthwise[0][0]']
#  chNormalization)
#
#  block_12_depthwise_relu (R  (None, 16, 16, 576)          0         ['block_12_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_12_project (Conv2D)   (None, 16, 16, 96)           55296     ['block_12_depthwise_relu[0][0
#                                                                     ]']
#
#  block_12_project_BN (Batch  (None, 16, 16, 96)           384       ['block_12_project[0][0]']
#  Normalization)
#
#  block_12_add (Add)          (None, 16, 16, 96)           0         ['tf.math.multiply_1[0][0]',
#                                                                      'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)    (None, 16, 16, 576)          55296     ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchN  (None, 16, 16, 576)          2304      ['block_13_expand[0][0]']
#  ormalization)
#
#  block_13_expand_relu (ReLU  (None, 16, 16, 576)          0         ['block_13_expand_BN[0][0]']
#  )
#
#  block_13_pad (ZeroPadding2  (None, 17, 17, 576)          0         ['block_13_expand_relu[0][0]']
#  D)
#
#  block_13_depthwise (Depthw  (None, 8, 8, 576)            5184      ['block_13_pad[0][0]']
#  iseConv2D)
#
#  block_13_depthwise_BN (Bat  (None, 8, 8, 576)            2304      ['block_13_depthwise[0][0]']
#  chNormalization)
#
#  block_13_depthwise_relu (R  (None, 8, 8, 576)            0         ['block_13_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_13_project (Conv2D)   (None, 8, 8, 160)            92160     ['block_13_depthwise_relu[0][0
#                                                                     ]']
#
#  block_13_project_BN (Batch  (None, 8, 8, 160)            640       ['block_13_project[0][0]']
#  Normalization)
#
#  block_14_expand (Conv2D)    (None, 8, 8, 960)            153600    ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchN  (None, 8, 8, 960)            3840      ['block_14_expand[0][0]']
#  ormalization)
#
#  block_14_expand_relu (ReLU  (None, 8, 8, 960)            0         ['block_14_expand_BN[0][0]']
#  )
#
#  block_14_depthwise (Depthw  (None, 8, 8, 960)            8640      ['block_14_expand_relu[0][0]']
#  iseConv2D)
#
#  block_14_depthwise_BN (Bat  (None, 8, 8, 960)            3840      ['block_14_depthwise[0][0]']
#  chNormalization)
#
#  block_14_depthwise_relu (R  (None, 8, 8, 960)            0         ['block_14_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_14_project (Conv2D)   (None, 8, 8, 160)            153600    ['block_14_depthwise_relu[0][0
#                                                                     ]']
#
#  block_14_project_BN (Batch  (None, 8, 8, 160)            640       ['block_14_project[0][0]']
#  Normalization)
#
#  block_14_add (Add)          (None, 8, 8, 160)            0         ['block_13_project_BN[0][0]',
#                                                                      'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)    (None, 8, 8, 960)            153600    ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchN  (None, 8, 8, 960)            3840      ['block_15_expand[0][0]']
#  ormalization)
#
#  block_15_expand_relu (ReLU  (None, 8, 8, 960)            0         ['block_15_expand_BN[0][0]']
#  )
#
#  block_15_depthwise (Depthw  (None, 8, 8, 960)            8640      ['block_15_expand_relu[0][0]']
#  iseConv2D)
#
#  block_15_depthwise_BN (Bat  (None, 8, 8, 960)            3840      ['block_15_depthwise[0][0]']
#  chNormalization)
#
#  block_15_depthwise_relu (R  (None, 8, 8, 960)            0         ['block_15_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_15_project (Conv2D)   (None, 8, 8, 160)            153600    ['block_15_depthwise_relu[0][0
#                                                                     ]']
#
#  block_15_project_BN (Batch  (None, 8, 8, 160)            640       ['block_15_project[0][0]']
#  Normalization)
#
#  block_15_add (Add)          (None, 8, 8, 160)            0         ['block_14_add[0][0]',
#                                                                      'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)    (None, 8, 8, 960)            153600    ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchN  (None, 8, 8, 960)            3840      ['block_16_expand[0][0]']
#  ormalization)
#
#  block_16_expand_relu (ReLU  (None, 8, 8, 960)            0         ['block_16_expand_BN[0][0]']
#  )
#
#  block_16_depthwise (Depthw  (None, 8, 8, 960)            8640      ['block_16_expand_relu[0][0]']
#  iseConv2D)
#
#  block_16_depthwise_BN (Bat  (None, 8, 8, 960)            3840      ['block_16_depthwise[0][0]']
#  chNormalization)
#
#  block_16_depthwise_relu (R  (None, 8, 8, 960)            0         ['block_16_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_16_project (Conv2D)   (None, 8, 8, 320)            307200    ['block_16_depthwise_relu[0][0
#                                                                     ]']
#
#  block_16_project_BN (Batch  (None, 8, 8, 320)            1280      ['block_16_project[0][0]']
#  Normalization)
#
#  Conv_1 (Conv2D)             (None, 8, 8, 1280)           409600    ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalizat  (None, 8, 8, 1280)           5120      ['Conv_1[0][0]']
#  ion)
#
#  out_relu (ReLU)             (None, 8, 8, 1280)           0         ['Conv_1_bn[0][0]']
#
#  global_average_pooling2d (  (None, 1280)                 0         ['out_relu[0][0]']
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)                 0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense (Dense)               (None, 8)                    10248     ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 2323912 (8.87 MB)
# Trainable params: 2289800 (8.73 MB)
# Non-trainable params: 34112 (133.25 KB)
# __________________________________________________________________________________________________

# %%
#@title Training the Models

# Train
logdir='/home/cmater/Desktop/Akash_MCSE/Surya/logs'
tensorboard_callback1 = tf.keras.callbacks.TensorBoard(log_dir=logdir)
tensorboard_callback2 = tf.keras.callbacks.ModelCheckpoint(
    filepath='/home/cmater/Desktop/Akash_MCSE/Surya/model.weights.h5',
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
    )

hist = model.fit(train, epochs=120, class_weight=class_weights, validation_data=val, callbacks=[tensorboard_callback1, tensorboard_callback2])
print(hist.history)
# Out:
# Epoch 1/120
# 346/346 [==============================] - ETA: 0s - loss: 1.5344 - accuracy: 0.8038
# Epoch 1: val_accuracy improved from -inf to 0.90434, saving model to /home/cmater/Desktop/Akash_MCSE/Surya/model.weights.h5
# 346/346 [==============================] - 82s 235ms/step - loss: 1.5344 - accuracy: 0.8038 - val_loss: 1.3097 - val_accuracy: 0.9043
# Epoch 2/120
# 346/346 [==============================] - ETA: 0s - loss: 1.5476 - accuracy: 0.7966
# Epoch 2: val_accuracy improved from 0.90434 to 0.91837, saving model to /home/cmater/Desktop/Akash_MCSE/Surya/model.weights.h5
# 346/346 [==============================] - 89s 255ms/step - loss: 1.5476 - accuracy: 0.7966 - val_loss: 1.2854 - val_accuracy: 0.9184
# Epoch 3/120
# 346/346 [==============================] - ETA: 0s - loss: 1.5375 - accuracy: 0.8049
# Epoch 3: val_accuracy did not improve from 0.91837
# 346/346 [==============================] - 98s 282ms/step - loss: 1.5375 - accuracy: 0.8049 - val_loss: 1.3002 - val_accuracy: 0.8967
# Epoch 4/120
# 346/346 [==============================] - ETA: 0s - loss: 1.5214 - accuracy: 0.8132
# Epoch 4: val_accuracy improved from 0.91837 to 0.92730, saving model to /home/cmater/Desktop/Akash_MCSE/Surya/model.weights.h5
# 346/346 [==============================] - 102s 294ms/step - loss: 1.5214 - accuracy: 0.8132 - val_loss: 1.2186 - val_accuracy: 0.9273
# Epoch 5/120
# 346/346 [==============================] - ETA: 0s - loss: 1.5438 - accuracy: 0.8049
# Epoch 5: val_accuracy did not improve from 0.92730
# 346/346 [==============================] - 101s 292ms/step - loss: 1.5438 - accuracy: 0.8049 - val_loss: 1.2806 - val_accuracy: 0.9209
# Epoch 6/120
# 346/346 [==============================] - ETA: 0s - loss: 1.4956 - accuracy: 0.8179
# Epoch 6: val_accuracy did not improve from 0.92730
# 346/346 [==============================] - 102s 295ms/step - loss: 1.4956 - accuracy: 0.8179 - val_loss: 1.2473 - val_accuracy: 0.9171
# Epoch 7/120
# 346/346 [==============================] - ETA: 0s - loss: 1.5207 - accuracy: 0.8078
# Epoch 7: val_accuracy did not improve from 0.92730
# 346/346 [==============================] - 101s 292ms/step - loss: 1.5207 - accuracy: 0.8078 - val_loss: 1.2695 - val_accuracy: 0.9209
# Epoch 8/120
# 346/346 [==============================] - ETA: 0s - loss: 1.5165 - accuracy: 0.8143
# Epoch 8: val_accuracy did not improve from 0.92730
# 346/346 [==============================] - 103s 296ms/step - loss: 1.5165 - accuracy: 0.8143 - val_loss: 1.2790 - val_accuracy: 0.9133
# Epoch 9/120
# 346/346 [==============================] - ETA: 0s - loss: 1.5153 - accuracy: 0.8125
# Epoch 9: val_accuracy improved from 0.92730 to 0.92985, saving model to /home/cmater/Desktop/Akash_MCSE/Surya/model.weights.h5
# 346/346 [==============================] - 102s 295ms/step - loss: 1.5153 - accuracy: 0.8125 - val_loss: 1.2089 - val_accuracy: 0.9298
# Epoch 10/120
# 346/346 [==============================] - ETA: 0s - loss: 1.4934 - accuracy: 0.8190
# Epoch 10: val_accuracy did not improve from 0.92985
# 346/346 [==============================] - 101s 291ms/step - loss: 1.4934 - accuracy: 0.8190 - val_loss: 1.2201 - val_accuracy: 0.9260
# Epoch 11/120
# 346/346 [==============================] - ETA: 0s - loss: 1.4902 - accuracy: 0.8195
# Epoch 11: val_accuracy improved from 0.92985 to 0.93495, saving model to /home/cmater/Desktop/Akash_MCSE/Surya/model.weights.h5
# 346/346 [==============================] - 103s 296ms/step - loss: 1.4902 - accuracy: 0.8195 - val_loss: 1.2610 - val_accuracy: 0.9349
# Epoch 12/120
# 346/346 [==============================] - ETA: 0s - loss: 1.5020 - accuracy: 0.8214
# Epoch 12: val_accuracy did not improve from 0.93495
# 346/346 [==============================] - 101s 291ms/step - loss: 1.5020 - accuracy: 0.8214 - val_loss: 1.2339 - val_accuracy: 0.9158
# Epoch 13/120
# 346/346 [==============================] - ETA: 0s - loss: 1.4682 - accuracy: 0.8331
# Epoch 13: val_accuracy did not improve from 0.93495
# 346/346 [==============================] - 102s 294ms/step - loss: 1.4682 - accuracy: 0.8331 - val_loss: 1.2506 - val_accuracy: 0.9145
# Epoch 14/120
# 346/346 [==============================] - ETA: 0s - loss: 1.4782 - accuracy: 0.8268
# Epoch 14: val_accuracy did not improve from 0.93495
# 346/346 [==============================] - 102s 294ms/step - loss: 1.4782 - accuracy: 0.8268 - val_loss: 1.2208 - val_accuracy: 0.9324
# Epoch 15/120
# 346/346 [==============================] - ETA: 0s - loss: 1.4680 - accuracy: 0.8316
# Epoch 15: val_accuracy improved from 0.93495 to 0.93622, saving model to /home/cmater/Desktop/Akash_MCSE/Surya/model.weights.h5
# 346/346 [==============================] - 102s 295ms/step - loss: 1.4680 - accuracy: 0.8316 - val_loss: 1.1981 - val_accuracy: 0.9362
# Epoch 16/120
# 346/346 [==============================] - ETA: 0s - loss: 1.4615 - accuracy: 0.8327
# Epoch 16: val_accuracy did not improve from 0.93622
# 346/346 [==============================] - 101s 292ms/step - loss: 1.4615 - accuracy: 0.8327 - val_loss: 1.2456 - val_accuracy: 0.9286
# Epoch 17/120
# 346/346 [==============================] - ETA: 0s - loss: 1.4597 - accuracy: 0.8311
# Epoch 17: val_accuracy improved from 0.93622 to 0.95408, saving model to /home/cmater/Desktop/Akash_MCSE/Surya/model.weights.h5
# 346/346 [==============================] - 103s 296ms/step - loss: 1.4597 - accuracy: 0.8311 - val_loss: 1.1931 - val_accuracy: 0.9541
# Epoch 18/120
# 346/346 [==============================] - ETA: 0s - loss: 1.4575 - accuracy: 0.8358
# Epoch 18: val_accuracy did not improve from 0.95408
# 346/346 [==============================] - 101s 292ms/step - loss: 1.4575 - accuracy: 0.8358 - val_loss: 1.1876 - val_accuracy: 0.9337
# Epoch 19/120
# 346/346 [==============================] - ETA: 0s - loss: 1.4721 - accuracy: 0.8340
# Epoch 19: val_accuracy did not improve from 0.95408
# 346/346 [==============================] - 101s 292ms/step - loss: 1.4721 - accuracy: 0.8340 - val_loss: 1.2337 - val_accuracy: 0.9286
# Epoch 20/120
# 346/346 [==============================] - ETA: 0s - loss: 1.4681 - accuracy: 0.8286
# Epoch 20: val_accuracy did not improve from 0.95408
# 346/346 [==============================] - 102s 294ms/step - loss: 1.4681 - accuracy: 0.8286 - val_loss: 1.2155 - val_accuracy: 0.9413
# Epoch 21/120
# 346/346 [==============================] - ETA: 0s - loss: 1.4621 - accuracy: 0.8333
# Epoch 21: val_accuracy did not improve from 0.95408
# 346/346 [==============================] - 101s 292ms/step - loss: 1.4621 - accuracy: 0.8333 - val_loss: 1.1913 - val_accuracy: 0.9515
# Epoch 22/120
# 346/346 [==============================] - ETA: 0s - loss: 1.4476 - accuracy: 0.8457
# Epoch 22: val_accuracy did not improve from 0.95408
# 346/346 [==============================] - 102s 294ms/step - loss: 1.4476 - accuracy: 0.8457 - val_loss: 1.1569 - val_accuracy: 0.9490
# Epoch 23/120
# 346/346 [==============================] - ETA: 0s - loss: 1.4399 - accuracy: 0.8439
# Epoch 23: val_accuracy did not improve from 0.95408
# 346/346 [==============================] - 101s 291ms/step - loss: 1.4399 - accuracy: 0.8439 - val_loss: 1.1666 - val_accuracy: 0.9439
# Epoch 24/120
# 346/346 [==============================] - ETA: 0s - loss: 1.4560 - accuracy: 0.8410
# Epoch 24: val_accuracy did not improve from 0.95408
# 346/346 [==============================] - 101s 293ms/step - loss: 1.4560 - accuracy: 0.8410 - val_loss: 1.1960 - val_accuracy: 0.9311
# Epoch 25/120
# 346/346 [==============================] - ETA: 0s - loss: 1.4639 - accuracy: 0.8335
# Epoch 25: val_accuracy did not improve from 0.95408
# 346/346 [==============================] - 101s 292ms/step - loss: 1.4639 - accuracy: 0.8335 - val_loss: 1.1672 - val_accuracy: 0.9439
# Epoch 26/120
# 346/346 [==============================] - ETA: 0s - loss: 1.4247 - accuracy: 0.8448
# Epoch 26: val_accuracy did not improve from 0.95408
# 346/346 [==============================] - 102s 294ms/step - loss: 1.4247 - accuracy: 0.8448 - val_loss: 1.1918 - val_accuracy: 0.9337
# Epoch 27/120
# 346/346 [==============================] - ETA: 0s - loss: 1.4254 - accuracy: 0.8486
# Epoch 27: val_accuracy did not improve from 0.95408
# 346/346 [==============================] - 102s 294ms/step - loss: 1.4254 - accuracy: 0.8486 - val_loss: 1.1786 - val_accuracy: 0.9349
# Epoch 28/120
# 346/346 [==============================] - ETA: 0s - loss: 1.4191 - accuracy: 0.8400
# Epoch 28: val_accuracy did not improve from 0.95408
# 346/346 [==============================] - 101s 292ms/step - loss: 1.4191 - accuracy: 0.8400 - val_loss: 1.1490 - val_accuracy: 0.9464
# Epoch 29/120
# 346/346 [==============================] - ETA: 0s - loss: 1.4337 - accuracy: 0.8463
# Epoch 29: val_accuracy improved from 0.95408 to 0.96046, saving model to /home/cmater/Desktop/Akash_MCSE/Surya/model.weights.h5
# 346/346 [==============================] - 102s 294ms/step - loss: 1.4337 - accuracy: 0.8463 - val_loss: 1.1285 - val_accuracy: 0.9605
# Epoch 30/120
# 346/346 [==============================] - ETA: 0s - loss: 1.4265 - accuracy: 0.8488
# Epoch 30: val_accuracy did not improve from 0.96046
# 346/346 [==============================] - 101s 292ms/step - loss: 1.4265 - accuracy: 0.8488 - val_loss: 1.1521 - val_accuracy: 0.9515
# Epoch 31/120
# 346/346 [==============================] - ETA: 0s - loss: 1.4315 - accuracy: 0.8477
# Epoch 31: val_accuracy did not improve from 0.96046
# 346/346 [==============================] - 101s 292ms/step - loss: 1.4315 - accuracy: 0.8477 - val_loss: 1.1635 - val_accuracy: 0.9413
# Epoch 32/120
# 346/346 [==============================] - ETA: 0s - loss: 1.4128 - accuracy: 0.8539
# Epoch 32: val_accuracy did not improve from 0.96046
# 346/346 [==============================] - 102s 295ms/step - loss: 1.4128 - accuracy: 0.8539 - val_loss: 1.1416 - val_accuracy: 0.9503
# Epoch 33/120
# 346/346 [==============================] - ETA: 0s - loss: 1.4112 - accuracy: 0.8439
# Epoch 33: val_accuracy did not improve from 0.96046
# 346/346 [==============================] - 102s 294ms/step - loss: 1.4112 - accuracy: 0.8439 - val_loss: 1.1601 - val_accuracy: 0.9528
# Epoch 34/120
# 346/346 [==============================] - ETA: 0s - loss: 1.4291 - accuracy: 0.8499
# Epoch 34: val_accuracy did not improve from 0.96046
# 346/346 [==============================] - 101s 292ms/step - loss: 1.4291 - accuracy: 0.8499 - val_loss: 1.2409 - val_accuracy: 0.9337
# Epoch 35/120
# 346/346 [==============================] - ETA: 0s - loss: 1.4024 - accuracy: 0.8530
# Epoch 35: val_accuracy did not improve from 0.96046
# 346/346 [==============================] - 102s 294ms/step - loss: 1.4024 - accuracy: 0.8530 - val_loss: 1.1250 - val_accuracy: 0.9554
# Epoch 36/120
# 346/346 [==============================] - ETA: 0s - loss: 1.4033 - accuracy: 0.8557
# Epoch 36: val_accuracy did not improve from 0.96046
# 346/346 [==============================] - 101s 291ms/step - loss: 1.4033 - accuracy: 0.8557 - val_loss: 1.1868 - val_accuracy: 0.9477
# Epoch 37/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3715 - accuracy: 0.8647
# Epoch 37: val_accuracy did not improve from 0.96046
# 346/346 [==============================] - 102s 294ms/step - loss: 1.3715 - accuracy: 0.8647 - val_loss: 1.1643 - val_accuracy: 0.9566
# Epoch 38/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3666 - accuracy: 0.8672
# Epoch 38: val_accuracy did not improve from 0.96046
# 346/346 [==============================] - 102s 294ms/step - loss: 1.3666 - accuracy: 0.8672 - val_loss: 1.1323 - val_accuracy: 0.9515
# Epoch 39/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3845 - accuracy: 0.8647
# Epoch 39: val_accuracy improved from 0.96046 to 0.96173, saving model to /home/cmater/Desktop/Akash_MCSE/Surya/model.weights.h5
# 346/346 [==============================] - 102s 293ms/step - loss: 1.3845 - accuracy: 0.8647 - val_loss: 1.1295 - val_accuracy: 0.9617
# Epoch 40/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3738 - accuracy: 0.8613
# Epoch 40: val_accuracy improved from 0.96173 to 0.96301, saving model to /home/cmater/Desktop/Akash_MCSE/Surya/model.weights.h5
# 346/346 [==============================] - 101s 291ms/step - loss: 1.3738 - accuracy: 0.8613 - val_loss: 1.1605 - val_accuracy: 0.9630
# Epoch 41/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3857 - accuracy: 0.8642
# Epoch 41: val_accuracy improved from 0.96301 to 0.96556, saving model to /home/cmater/Desktop/Akash_MCSE/Surya/model.weights.h5
# 346/346 [==============================] - 102s 293ms/step - loss: 1.3857 - accuracy: 0.8642 - val_loss: 1.1113 - val_accuracy: 0.9656
# Epoch 42/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3835 - accuracy: 0.8636
# Epoch 42: val_accuracy did not improve from 0.96556
# 346/346 [==============================] - 100s 290ms/step - loss: 1.3835 - accuracy: 0.8636 - val_loss: 1.1415 - val_accuracy: 0.9630
# Epoch 43/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3647 - accuracy: 0.8687
# Epoch 43: val_accuracy did not improve from 0.96556
# 346/346 [==============================] - 102s 294ms/step - loss: 1.3647 - accuracy: 0.8687 - val_loss: 1.1285 - val_accuracy: 0.9579
# Epoch 44/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3750 - accuracy: 0.8611
# Epoch 44: val_accuracy did not improve from 0.96556
# 346/346 [==============================] - 101s 292ms/step - loss: 1.3750 - accuracy: 0.8611 - val_loss: 1.1462 - val_accuracy: 0.9579
# Epoch 45/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3655 - accuracy: 0.8696
# Epoch 45: val_accuracy did not improve from 0.96556
# 346/346 [==============================] - 101s 291ms/step - loss: 1.3655 - accuracy: 0.8696 - val_loss: 1.1273 - val_accuracy: 0.9566
# Epoch 46/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3701 - accuracy: 0.8746
# Epoch 46: val_accuracy did not improve from 0.96556
# 346/346 [==============================] - 102s 293ms/step - loss: 1.3701 - accuracy: 0.8746 - val_loss: 1.1164 - val_accuracy: 0.9566
# Epoch 47/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3551 - accuracy: 0.8714
# Epoch 47: val_accuracy did not improve from 0.96556
# 346/346 [==============================] - 100s 290ms/step - loss: 1.3551 - accuracy: 0.8714 - val_loss: 1.0980 - val_accuracy: 0.9617
# Epoch 48/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3420 - accuracy: 0.8759
# Epoch 48: val_accuracy improved from 0.96556 to 0.96939, saving model to /home/cmater/Desktop/Akash_MCSE/Surya/model.weights.h5
# 346/346 [==============================] - 102s 295ms/step - loss: 1.3420 - accuracy: 0.8759 - val_loss: 1.1111 - val_accuracy: 0.9694
# Epoch 49/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3422 - accuracy: 0.8727
# Epoch 49: val_accuracy did not improve from 0.96939
# 346/346 [==============================] - 101s 290ms/step - loss: 1.3422 - accuracy: 0.8727 - val_loss: 1.1299 - val_accuracy: 0.9579
# Epoch 50/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3535 - accuracy: 0.8734
# Epoch 50: val_accuracy improved from 0.96939 to 0.97066, saving model to /home/cmater/Desktop/Akash_MCSE/Surya/model.weights.h5
# 346/346 [==============================] - 102s 294ms/step - loss: 1.3535 - accuracy: 0.8734 - val_loss: 1.0990 - val_accuracy: 0.9707
# Epoch 51/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3527 - accuracy: 0.8743
# Epoch 51: val_accuracy did not improve from 0.97066
# 346/346 [==============================] - 101s 292ms/step - loss: 1.3527 - accuracy: 0.8743 - val_loss: 1.1740 - val_accuracy: 0.9464
# Epoch 52/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3452 - accuracy: 0.8750
# Epoch 52: val_accuracy improved from 0.97066 to 0.98214, saving model to /home/cmater/Desktop/Akash_MCSE/Surya/model.weights.h5
# 346/346 [==============================] - 102s 293ms/step - loss: 1.3452 - accuracy: 0.8750 - val_loss: 1.0752 - val_accuracy: 0.9821
# Epoch 53/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3425 - accuracy: 0.8746
# Epoch 53: val_accuracy did not improve from 0.98214
# 346/346 [==============================] - 101s 290ms/step - loss: 1.3425 - accuracy: 0.8746 - val_loss: 1.0906 - val_accuracy: 0.9758
# Epoch 54/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3320 - accuracy: 0.8788
# Epoch 54: val_accuracy did not improve from 0.98214
# 346/346 [==============================] - 102s 293ms/step - loss: 1.3320 - accuracy: 0.8788 - val_loss: 1.1345 - val_accuracy: 0.9668
# Epoch 55/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3384 - accuracy: 0.8748
# Epoch 55: val_accuracy did not improve from 0.98214
# 346/346 [==============================] - 102s 293ms/step - loss: 1.3384 - accuracy: 0.8748 - val_loss: 1.0789 - val_accuracy: 0.9758
# Epoch 56/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3130 - accuracy: 0.8860
# Epoch 56: val_accuracy did not improve from 0.98214
# 346/346 [==============================] - 101s 291ms/step - loss: 1.3130 - accuracy: 0.8860 - val_loss: 1.0962 - val_accuracy: 0.9745
# Epoch 57/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3347 - accuracy: 0.8788
# Epoch 57: val_accuracy did not improve from 0.98214
# 346/346 [==============================] - 101s 293ms/step - loss: 1.3347 - accuracy: 0.8788 - val_loss: 1.0932 - val_accuracy: 0.9758
# Epoch 58/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3473 - accuracy: 0.8768
# Epoch 58: val_accuracy did not improve from 0.98214
# 346/346 [==============================] - 100s 290ms/step - loss: 1.3473 - accuracy: 0.8768 - val_loss: 1.0891 - val_accuracy: 0.9745
# Epoch 59/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3074 - accuracy: 0.8907
# Epoch 59: val_accuracy did not improve from 0.98214
# 346/346 [==============================] - 102s 293ms/step - loss: 1.3074 - accuracy: 0.8907 - val_loss: 1.0975 - val_accuracy: 0.9732
# Epoch 60/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3043 - accuracy: 0.8923
# Epoch 60: val_accuracy did not improve from 0.98214
# 346/346 [==============================] - 101s 292ms/step - loss: 1.3043 - accuracy: 0.8923 - val_loss: 1.1201 - val_accuracy: 0.9566
# Epoch 61/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3224 - accuracy: 0.8855
# Epoch 61: val_accuracy did not improve from 0.98214
# 346/346 [==============================] - 101s 292ms/step - loss: 1.3224 - accuracy: 0.8855 - val_loss: 1.0805 - val_accuracy: 0.9770
# Epoch 62/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2814 - accuracy: 0.8987
# Epoch 62: val_accuracy did not improve from 0.98214
# 346/346 [==============================] - 102s 293ms/step - loss: 1.2814 - accuracy: 0.8987 - val_loss: 1.0995 - val_accuracy: 0.9745
# Epoch 63/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3211 - accuracy: 0.8880
# Epoch 63: val_accuracy did not improve from 0.98214
# 346/346 [==============================] - 101s 292ms/step - loss: 1.3211 - accuracy: 0.8880 - val_loss: 1.0831 - val_accuracy: 0.9821
# Epoch 64/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3112 - accuracy: 0.8860
# Epoch 64: val_accuracy did not improve from 0.98214
# 346/346 [==============================] - 102s 293ms/step - loss: 1.3112 - accuracy: 0.8860 - val_loss: 1.0788 - val_accuracy: 0.9758
# Epoch 65/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3188 - accuracy: 0.8851
# Epoch 65: val_accuracy did not improve from 0.98214
# 346/346 [==============================] - 101s 293ms/step - loss: 1.3188 - accuracy: 0.8851 - val_loss: 1.1631 - val_accuracy: 0.9503
# Epoch 66/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3048 - accuracy: 0.8922
# Epoch 66: val_accuracy did not improve from 0.98214
# 346/346 [==============================] - 101s 292ms/step - loss: 1.3048 - accuracy: 0.8922 - val_loss: 1.0770 - val_accuracy: 0.9821
# Epoch 67/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2876 - accuracy: 0.9017
# Epoch 67: val_accuracy did not improve from 0.98214
# 346/346 [==============================] - 101s 291ms/step - loss: 1.2876 - accuracy: 0.9017 - val_loss: 1.0649 - val_accuracy: 0.9809
# Epoch 68/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2941 - accuracy: 0.8967
# Epoch 68: val_accuracy did not improve from 0.98214
# 346/346 [==============================] - 101s 292ms/step - loss: 1.2941 - accuracy: 0.8967 - val_loss: 1.0889 - val_accuracy: 0.9719
# Epoch 69/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2742 - accuracy: 0.9016
# Epoch 69: val_accuracy did not improve from 0.98214
# 346/346 [==============================] - 102s 293ms/step - loss: 1.2742 - accuracy: 0.9016 - val_loss: 1.0720 - val_accuracy: 0.9770
# Epoch 70/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3041 - accuracy: 0.8938
# Epoch 70: val_accuracy did not improve from 0.98214
# 346/346 [==============================] - 101s 291ms/step - loss: 1.3041 - accuracy: 0.8938 - val_loss: 1.0880 - val_accuracy: 0.9758
# Epoch 71/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2795 - accuracy: 0.9005
# Epoch 71: val_accuracy did not improve from 0.98214
# 346/346 [==============================] - 101s 292ms/step - loss: 1.2795 - accuracy: 0.9005 - val_loss: 1.0810 - val_accuracy: 0.9821
# Epoch 72/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2766 - accuracy: 0.9088
# Epoch 72: val_accuracy did not improve from 0.98214
# 346/346 [==============================] - 102s 293ms/step - loss: 1.2766 - accuracy: 0.9088 - val_loss: 1.0697 - val_accuracy: 0.9758
# Epoch 73/120
# 346/346 [==============================] - ETA: 0s - loss: 1.3009 - accuracy: 0.8891
# Epoch 73: val_accuracy did not improve from 0.98214
# 346/346 [==============================] - 101s 292ms/step - loss: 1.3009 - accuracy: 0.8891 - val_loss: 1.0758 - val_accuracy: 0.9681
# Epoch 74/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2974 - accuracy: 0.8951
# Epoch 74: val_accuracy did not improve from 0.98214
# 346/346 [==============================] - 101s 292ms/step - loss: 1.2974 - accuracy: 0.8951 - val_loss: 1.0715 - val_accuracy: 0.9770
# Epoch 75/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2998 - accuracy: 0.8923
# Epoch 75: val_accuracy did not improve from 0.98214
# 346/346 [==============================] - 102s 293ms/step - loss: 1.2998 - accuracy: 0.8923 - val_loss: 1.0757 - val_accuracy: 0.9732
# Epoch 76/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2813 - accuracy: 0.9007
# Epoch 76: val_accuracy did not improve from 0.98214
# 346/346 [==============================] - 101s 291ms/step - loss: 1.2813 - accuracy: 0.9007 - val_loss: 1.0770 - val_accuracy: 0.9821
# Epoch 77/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2902 - accuracy: 0.9008
# Epoch 77: val_accuracy did not improve from 0.98214
# 346/346 [==============================] - 101s 292ms/step - loss: 1.2902 - accuracy: 0.9008 - val_loss: 1.0727 - val_accuracy: 0.9770
# Epoch 78/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2713 - accuracy: 0.9053
# Epoch 78: val_accuracy improved from 0.98214 to 0.98469, saving model to /home/cmater/Desktop/Akash_MCSE/Surya/model.weights.h5
# 346/346 [==============================] - 102s 296ms/step - loss: 1.2713 - accuracy: 0.9053 - val_loss: 1.0595 - val_accuracy: 0.9847
# Epoch 79/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2513 - accuracy: 0.9093
# Epoch 79: val_accuracy did not improve from 0.98469
# 346/346 [==============================] - 101s 291ms/step - loss: 1.2513 - accuracy: 0.9093 - val_loss: 1.0712 - val_accuracy: 0.9796
# Epoch 80/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2646 - accuracy: 0.9086
# Epoch 80: val_accuracy improved from 0.98469 to 0.98724, saving model to /home/cmater/Desktop/Akash_MCSE/Surya/model.weights.h5
# 346/346 [==============================] - 102s 295ms/step - loss: 1.2646 - accuracy: 0.9086 - val_loss: 1.0610 - val_accuracy: 0.9872
# Epoch 81/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2566 - accuracy: 0.9062
# Epoch 81: val_accuracy did not improve from 0.98724
# 346/346 [==============================] - 100s 289ms/step - loss: 1.2566 - accuracy: 0.9062 - val_loss: 1.0646 - val_accuracy: 0.9809
# Epoch 82/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2266 - accuracy: 0.9196
# Epoch 82: val_accuracy did not improve from 0.98724
# 346/346 [==============================] - 102s 293ms/step - loss: 1.2266 - accuracy: 0.9196 - val_loss: 1.0609 - val_accuracy: 0.9783
# Epoch 83/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2523 - accuracy: 0.9106
# Epoch 83: val_accuracy did not improve from 0.98724
# 346/346 [==============================] - 102s 293ms/step - loss: 1.2523 - accuracy: 0.9106 - val_loss: 1.0551 - val_accuracy: 0.9809
# Epoch 84/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2657 - accuracy: 0.9061
# Epoch 84: val_accuracy did not improve from 0.98724
# 346/346 [==============================] - 102s 293ms/step - loss: 1.2657 - accuracy: 0.9061 - val_loss: 1.0608 - val_accuracy: 0.9809
# Epoch 85/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2697 - accuracy: 0.9084
# Epoch 85: val_accuracy did not improve from 0.98724
# 346/346 [==============================] - 102s 293ms/step - loss: 1.2697 - accuracy: 0.9084 - val_loss: 1.0561 - val_accuracy: 0.9783
# Epoch 86/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2577 - accuracy: 0.9086
# Epoch 86: val_accuracy did not improve from 0.98724
# 346/346 [==============================] - 101s 292ms/step - loss: 1.2577 - accuracy: 0.9086 - val_loss: 1.0822 - val_accuracy: 0.9834
# Epoch 87/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2626 - accuracy: 0.9072
# Epoch 87: val_accuracy did not improve from 0.98724
# 346/346 [==============================] - 101s 292ms/step - loss: 1.2626 - accuracy: 0.9072 - val_loss: 1.0500 - val_accuracy: 0.9834
# Epoch 88/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2633 - accuracy: 0.9073
# Epoch 88: val_accuracy did not improve from 0.98724
# 346/346 [==============================] - 102s 293ms/step - loss: 1.2633 - accuracy: 0.9073 - val_loss: 1.1176 - val_accuracy: 0.9719
# Epoch 89/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2585 - accuracy: 0.9106
# Epoch 89: val_accuracy did not improve from 0.98724
# 346/346 [==============================] - 102s 293ms/step - loss: 1.2585 - accuracy: 0.9106 - val_loss: 1.0598 - val_accuracy: 0.9834
# Epoch 90/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2488 - accuracy: 0.9109
# Epoch 90: val_accuracy did not improve from 0.98724
# 346/346 [==============================] - 101s 292ms/step - loss: 1.2488 - accuracy: 0.9109 - val_loss: 1.0469 - val_accuracy: 0.9860
# Epoch 91/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2516 - accuracy: 0.9124
# Epoch 91: val_accuracy did not improve from 0.98724
# 346/346 [==============================] - 102s 293ms/step - loss: 1.2516 - accuracy: 0.9124 - val_loss: 1.0517 - val_accuracy: 0.9809
# Epoch 92/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2390 - accuracy: 0.9167
# Epoch 92: val_accuracy improved from 0.98724 to 0.98852, saving model to /home/cmater/Desktop/Akash_MCSE/Surya/model.weights.h5
# 346/346 [==============================] - 102s 295ms/step - loss: 1.2390 - accuracy: 0.9167 - val_loss: 1.0434 - val_accuracy: 0.9885
# Epoch 93/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2653 - accuracy: 0.9064
# Epoch 93: val_accuracy did not improve from 0.98852
# 346/346 [==============================] - 101s 291ms/step - loss: 1.2653 - accuracy: 0.9064 - val_loss: 1.0672 - val_accuracy: 0.9847
# Epoch 94/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2392 - accuracy: 0.9144
# Epoch 94: val_accuracy did not improve from 0.98852
# 346/346 [==============================] - 101s 292ms/step - loss: 1.2392 - accuracy: 0.9144 - val_loss: 1.0547 - val_accuracy: 0.9821
# Epoch 95/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2379 - accuracy: 0.9160
# Epoch 95: val_accuracy did not improve from 0.98852
# 346/346 [==============================] - 101s 292ms/step - loss: 1.2379 - accuracy: 0.9160 - val_loss: 1.0453 - val_accuracy: 0.9872
# Epoch 96/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2308 - accuracy: 0.9137
# Epoch 96: val_accuracy did not improve from 0.98852
# 346/346 [==============================] - 102s 293ms/step - loss: 1.2308 - accuracy: 0.9137 - val_loss: 1.0446 - val_accuracy: 0.9860
# Epoch 97/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2486 - accuracy: 0.9124
# Epoch 97: val_accuracy did not improve from 0.98852
# 346/346 [==============================] - 102s 293ms/step - loss: 1.2486 - accuracy: 0.9124 - val_loss: 1.0665 - val_accuracy: 0.9681
# Epoch 98/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2397 - accuracy: 0.9160
# Epoch 98: val_accuracy did not improve from 0.98852
# 346/346 [==============================] - 101s 293ms/step - loss: 1.2397 - accuracy: 0.9160 - val_loss: 1.0446 - val_accuracy: 0.9860
# Epoch 99/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2149 - accuracy: 0.9221
# Epoch 99: val_accuracy did not improve from 0.98852
# 346/346 [==============================] - 102s 294ms/step - loss: 1.2149 - accuracy: 0.9221 - val_loss: 1.0537 - val_accuracy: 0.9847
# Epoch 100/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2591 - accuracy: 0.9120
# Epoch 100: val_accuracy did not improve from 0.98852
# 346/346 [==============================] - 101s 291ms/step - loss: 1.2591 - accuracy: 0.9120 - val_loss: 1.0485 - val_accuracy: 0.9847
# Epoch 101/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2261 - accuracy: 0.9234
# Epoch 101: val_accuracy did not improve from 0.98852
# 346/346 [==============================] - 101s 292ms/step - loss: 1.2261 - accuracy: 0.9234 - val_loss: 1.0423 - val_accuracy: 0.9847
# Epoch 102/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2159 - accuracy: 0.9277
# Epoch 102: val_accuracy did not improve from 0.98852
# 346/346 [==============================] - 102s 294ms/step - loss: 1.2159 - accuracy: 0.9277 - val_loss: 1.0501 - val_accuracy: 0.9834
# Epoch 103/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2053 - accuracy: 0.9252
# Epoch 103: val_accuracy did not improve from 0.98852
# 346/346 [==============================] - 101s 292ms/step - loss: 1.2053 - accuracy: 0.9252 - val_loss: 1.0389 - val_accuracy: 0.9860
# Epoch 104/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2227 - accuracy: 0.9156
# Epoch 104: val_accuracy did not improve from 0.98852
# 346/346 [==============================] - 101s 292ms/step - loss: 1.2227 - accuracy: 0.9156 - val_loss: 1.0383 - val_accuracy: 0.9847
# Epoch 105/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2045 - accuracy: 0.9285
# Epoch 105: val_accuracy did not improve from 0.98852
# 346/346 [==============================] - 101s 291ms/step - loss: 1.2045 - accuracy: 0.9285 - val_loss: 1.0386 - val_accuracy: 0.9885
# Epoch 106/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2203 - accuracy: 0.9187
# Epoch 106: val_accuracy did not improve from 0.98852
# 346/346 [==============================] - 102s 294ms/step - loss: 1.2203 - accuracy: 0.9187 - val_loss: 1.0356 - val_accuracy: 0.9872
# Epoch 107/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2186 - accuracy: 0.9254
# Epoch 107: val_accuracy did not improve from 0.98852
# 346/346 [==============================] - 102s 294ms/step - loss: 1.2186 - accuracy: 0.9254 - val_loss: 1.0437 - val_accuracy: 0.9821
# Epoch 108/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2032 - accuracy: 0.9286
# Epoch 108: val_accuracy did not improve from 0.98852
# 346/346 [==============================] - 102s 293ms/step - loss: 1.2032 - accuracy: 0.9286 - val_loss: 1.0641 - val_accuracy: 0.9758
# Epoch 109/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2201 - accuracy: 0.9205
# Epoch 109: val_accuracy did not improve from 0.98852
# 346/346 [==============================] - 102s 293ms/step - loss: 1.2201 - accuracy: 0.9205 - val_loss: 1.0455 - val_accuracy: 0.9872
# Epoch 110/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2321 - accuracy: 0.9187
# Epoch 110: val_accuracy did not improve from 0.98852
# 346/346 [==============================] - 101s 292ms/step - loss: 1.2321 - accuracy: 0.9187 - val_loss: 1.0459 - val_accuracy: 0.9821
# Epoch 111/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2271 - accuracy: 0.9221
# Epoch 111: val_accuracy did not improve from 0.98852
# 346/346 [==============================] - 102s 293ms/step - loss: 1.2271 - accuracy: 0.9221 - val_loss: 1.0550 - val_accuracy: 0.9758
# Epoch 112/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2221 - accuracy: 0.9245
# Epoch 112: val_accuracy did not improve from 0.98852
# 346/346 [==============================] - 101s 293ms/step - loss: 1.2221 - accuracy: 0.9245 - val_loss: 1.0372 - val_accuracy: 0.9860
# Epoch 113/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2095 - accuracy: 0.9249
# Epoch 113: val_accuracy did not improve from 0.98852
# 346/346 [==============================] - 102s 293ms/step - loss: 1.2095 - accuracy: 0.9249 - val_loss: 1.0462 - val_accuracy: 0.9872
# Epoch 114/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2085 - accuracy: 0.9259
# Epoch 114: val_accuracy did not improve from 0.98852
# 346/346 [==============================] - 102s 293ms/step - loss: 1.2085 - accuracy: 0.9259 - val_loss: 1.0513 - val_accuracy: 0.9809
# Epoch 115/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2059 - accuracy: 0.9276
# Epoch 115: val_accuracy did not improve from 0.98852
# 346/346 [==============================] - 101s 292ms/step - loss: 1.2059 - accuracy: 0.9276 - val_loss: 1.0349 - val_accuracy: 0.9885
# Epoch 116/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2124 - accuracy: 0.9236
# Epoch 116: val_accuracy did not improve from 0.98852
# 346/346 [==============================] - 101s 292ms/step - loss: 1.2124 - accuracy: 0.9236 - val_loss: 1.0396 - val_accuracy: 0.9860
# Epoch 117/120
# 346/346 [==============================] - ETA: 0s - loss: 1.1937 - accuracy: 0.9314
# Epoch 117: val_accuracy did not improve from 0.98852
# 346/346 [==============================] - 102s 294ms/step - loss: 1.1937 - accuracy: 0.9314 - val_loss: 1.0351 - val_accuracy: 0.9885
# Epoch 118/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2029 - accuracy: 0.9285
# Epoch 118: val_accuracy did not improve from 0.98852
# 346/346 [==============================] - 100s 289ms/step - loss: 1.2029 - accuracy: 0.9285 - val_loss: 1.0447 - val_accuracy: 0.9847
# Epoch 119/120
# 346/346 [==============================] - ETA: 0s - loss: 1.1980 - accuracy: 0.9306
# Epoch 119: val_accuracy improved from 0.98852 to 0.99107, saving model to /home/cmater/Desktop/Akash_MCSE/Surya/model.weights.h5
# 346/346 [==============================] - 103s 297ms/step - loss: 1.1980 - accuracy: 0.9306 - val_loss: 1.0334 - val_accuracy: 0.9911
# Epoch 120/120
# 346/346 [==============================] - ETA: 0s - loss: 1.2081 - accuracy: 0.9265
# Epoch 120: val_accuracy did not improve from 0.99107
# 346/346 [==============================] - 101s 290ms/step - loss: 1.2081 - accuracy: 0.9265 - val_loss: 1.0460 - val_accuracy: 0.9834
# {'loss': [1.5344195365905762, 1.547588586807251, 1.537454605102539, 1.5214357376098633, 1.5438132286071777, 1.4956316947937012, 1.5207222700119019, 1.516514539718628, 1.515317678451538, 1.4933769702911377, 1.4901666641235352, 1.5020307302474976, 1.4681713581085205, 1.478196620941162, 1.467991828918457, 1.461462378501892, 1.4597498178482056, 1.4574629068374634, 1.4721112251281738, 1.468146800994873, 1.4621319770812988, 1.4475709199905396, 1.439926266670227, 1.4559507369995117, 1.46392822265625, 1.4247325658798218, 1.4254088401794434, 1.419076681137085, 1.4337364435195923, 1.4265135526657104, 1.4314676523208618, 1.412789225578308, 1.4112279415130615, 1.429073691368103, 1.4023767709732056, 1.403260588645935, 1.3715142011642456, 1.366563320159912, 1.3844728469848633, 1.3737527132034302, 1.3857035636901855, 1.3835281133651733, 1.3647003173828125, 1.375002384185791, 1.3655370473861694, 1.3701224327087402, 1.3550615310668945, 1.3420274257659912, 1.3422154188156128, 1.3534733057022095, 1.3527090549468994, 1.345191240310669, 1.3425288200378418, 1.3320015668869019, 1.338350772857666, 1.3129979372024536, 1.3347028493881226, 1.3472871780395508, 1.307418942451477, 1.3042757511138916, 1.322361946105957, 1.2813693284988403, 1.3211368322372437, 1.311189889907837, 1.3187931776046753, 1.304829716682434, 1.287581443786621, 1.294118046760559, 1.2741855382919312, 1.3041253089904785, 1.2795445919036865, 1.2766215801239014, 1.300887107849121, 1.297372817993164, 1.2998483180999756, 1.2813353538513184, 1.290234923362732, 1.271344780921936, 1.2513377666473389, 1.2646468877792358, 1.2566355466842651, 1.2266414165496826, 1.2523069381713867, 1.2656632661819458, 1.269727110862732, 1.2576909065246582, 1.262558102607727, 1.2633075714111328, 1.2585479021072388, 1.2488272190093994, 1.2515672445297241, 1.2389577627182007, 1.2653449773788452, 1.2391972541809082, 1.2378500699996948, 1.2308334112167358, 1.2485781908035278, 1.2397222518920898, 1.2149409055709839, 1.2590858936309814, 1.2261465787887573, 1.2158821821212769, 1.2053236961364746, 1.2227115631103516, 1.2044544219970703, 1.2203037738800049, 1.218556523323059, 1.203165888786316, 1.2200888395309448, 1.2321248054504395, 1.2271169424057007, 1.2221139669418335, 1.209513783454895, 1.2085258960723877, 1.205863118171692, 1.2123661041259766, 1.193706750869751, 1.2028720378875732, 1.1979597806930542, 1.2081385850906372], 'accuracy': [0.8038294911384583, 0.7966040372848511, 0.8049132823944092, 0.8132225275039673, 0.8049132823944092, 0.8179190754890442, 0.8078034520149231, 0.814306378364563, 0.8125, 0.8190028667449951, 0.819544792175293, 0.821351170539856, 0.8330925107002258, 0.8267702460289001, 0.8316473960876465, 0.8327311873435974, 0.8311054706573486, 0.8358020186424255, 0.8339956402778625, 0.8285765647888184, 0.8332731127738953, 0.8457369804382324, 0.8439306616783142, 0.8410404920578003, 0.8334537744522095, 0.8448337912559509, 0.8486271500587463, 0.8399566411972046, 0.8462789058685303, 0.8488078117370605, 0.8477239608764648, 0.8538656234741211, 0.8439306616783142, 0.8498916029930115, 0.8529624342918396, 0.8556719422340393, 0.8647037744522095, 0.8672326803207397, 0.8647037744522095, 0.8612716794013977, 0.8641618490219116, 0.8636199235916138, 0.8686777353286743, 0.8610910177230835, 0.8695809245109558, 0.8746387362480164, 0.8713873028755188, 0.8759031891822815, 0.8726517558097839, 0.8733742833137512, 0.8742774724960327, 0.875, 0.8746387362480164, 0.8787933588027954, 0.8748193383216858, 0.8860188126564026, 0.8787933588027954, 0.876806378364563, 0.8907153010368347, 0.8923410177230835, 0.8854768872261047, 0.8986632823944092, 0.888005793094635, 0.8860188126564026, 0.8851156234741211, 0.8921604156494141, 0.9017341136932373, 0.8966763019561768, 0.9015534520149231, 0.8937861323356628, 0.9004696607589722, 0.9087789058685303, 0.8890895843505859, 0.895050585269928, 0.8923410177230835, 0.9006502628326416, 0.9008309245109558, 0.9053468108177185, 0.9093208312988281, 0.9085982441902161, 0.90625, 0.9196170568466187, 0.910585284233 ...

# %%
#@title Evaluating the Model

''' Evaluation '''
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy, sparse_categorical_accuracy
from sklearn.metrics import *

model.load_weights("/home/cmater/Desktop/Akash_MCSE/Surya/model.weights.h5")
loss, results = model.evaluate(test, batch_size=328, callbacks=[tensorboard_callback1, tensorboard_callback2])
print("Result : \n", results)
print("Loss: \n", loss)

''' MobileNetV2 '''
print("For MobileNetV2: ")
pre = Precision()
re = Recall()
acc = BinaryAccuracy()
labels = []
predicts = []
pre3 = Precision()
re3 = Recall()
acc3 = BinaryAccuracy()
for batch3 in test.as_numpy_iterator():
    X3, y3 = batch3
    labels.extend(list(y3))
    yhat3 = model.predict(X3, verbose=0)
    max = a = 0
    arr = np.ones(yhat3.shape[0])*-1
    for i in yhat3:
        max = np.argmax(i)
        arr[a] = max
        a+=1
    predicts.extend(list(arr))
    pre3.update_state(y3, arr)
    re3.update_state(y3, arr)
    acc3.update_state(y3, arr)
acc31 = sparse_categorical_accuracy(y3, yhat3)
assert acc31.shape == (y3.shape[0],)
print(f'Precision:{pre3.result().numpy()}, Recall:{re3.result().numpy()}, Accuracy (Binary):{acc3.result().numpy()}, Accuracy (sparse_categorical):{acc31.numpy()}')
matrix = confusion_matrix(y3, arr)
print("Confusion Matrix for Model: \n", matrix)
display = ConfusionMatrixDisplay(confusion_matrix = matrix, display_labels = os.listdir("/home/cmater/Desktop/Akash_MCSE/Surya/breakhis-dataset-expanded")) #['Benign', 'Malignant'])
display.plot()
plt.show()

print("For Test Dataset: ")
pre.update_state(labels, predicts)
re.update_state(labels, predicts)
acc.update_state(labels, predicts)
print(f'Precision:{pre.result().numpy()}, Recall:{re.result().numpy()}, Accuracy (Binary):{acc.result().numpy()}')
matrix = confusion_matrix(labels, predicts)
print("Confusion Matrix for MobileNetV2 on Test Dataset: \n", matrix)
display = ConfusionMatrixDisplay(confusion_matrix = matrix, display_labels = os.listdir("/home/cmater/Desktop/Akash_MCSE/Surya/breakhis-dataset-expanded")) #['Benign', 'Malignant'])
display.plot()
plt.show()

# %%
#@title Performance Graphs

import matplotlib.pyplot as plt

# Loss
fig = plt.figure()
plt.title("MobileNetV2\n\n", loc='center', fontsize=26)
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# Accuracy
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
#@title ROC-AUC Curves

import pandas as pd
import numpy as np
from sklearn.metrics import *
import math, os
from sklearn.preprocessing import label_binarize

#ROC-AUC
from sklearn.metrics import roc_curve,auc
import matplotlib.pyplot as plt
def plot_roc(val_label,decision_val, caption='ROC Curve'):
    num_classes=np.unique(val_label).shape[0]
    classes = []
    for i in range(num_classes):
        classes.append(i)
    plt.figure()
    decision_val = label_binarize(decision_val, classes=classes)

    if num_classes!=2:
        # Compute ROC curve and ROC area for each class
        fpr = dict()
        tpr = dict()
        roc_auc = dict()
        for i in range(num_classes):
            y_val = label_binarize(val_label, classes=classes)
            fpr[i], tpr[i], _ = roc_curve(y_val[:, i], decision_val[:, i])
            roc_auc[i] = auc(fpr[i], tpr[i])
        for i in range(num_classes):
            plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
                                           ''.format(i+1, roc_auc[i]))
    else:
        fpr,tpr,_ = roc_curve(val_label,decision_val, pos_label=1)
        roc_auc = auc(fpr,tpr)*100
        plt.plot(fpr,tpr,label='ROC curve (AUC=%0.2f)'%roc_auc)

    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(caption)
    plt.legend(loc="lower right",  bbox_to_anchor=(1, 0.5))
    plt.savefig(str(len(classes))+'.png',dpi=300)

def predicting(ensemble_prob):
    prediction = np.zeros((ensemble_prob.shape[0],))
    for i in range(ensemble_prob.shape[0]):
        temp = ensemble_prob[i]
        t = np.where(temp == np.max(temp))[0][0]
        prediction[i] = t
    return prediction

def metrics(labels, predictions, classes, display_label):
    print("Classification Report:")
    print("Labels : ",labels.shape, '\nPredictions : ', predictions.shape)
    print(classification_report(labels, predictions, target_names = classes, digits = 4))
    matrix = confusion_matrix(labels, predictions)
    print("Confusion matrix:")
    print(matrix)
    plt.figure()
    display = ConfusionMatrixDisplay(confusion_matrix = matrix, display_labels = display_label)
    display.plot()
    plt.xticks(rotation=50)
    plt.show()
    print("\nClasswise Accuracy :{}".format(matrix.diagonal()/matrix.sum(axis = 1)))
    print("\nBalanced Accuracy Score: ",balanced_accuracy_score(labels,predictions))

# %%
#@title Precision, Recall and Accuracy of the Models with respect to test dataset

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

labels = []
p = []
p1 = []
for batch in test.as_numpy_iterator():
    X, y = batch
    labels.extend(list(y))
    yhat = model.predict(X, verbose=0)
    max = 0
    for i in yhat:
        max = np.argmax(i)
        p.append(max)
        p1.append(i)

labels = np.asarray(labels)
p = np.asarray(p)

import csv
fp = open("/home/cmater/Desktop/Akash_MCSE/Surya/test.csv",'w+',newline = '')
writer = csv.writer(fp)
for i in p1:
    writer.writerow([i[0], i[1], i[2], i[3], i[4], i[5], i[6], i[7]])
fp.close()

fp = open("/home/cmater/Desktop/Akash_MCSE/Surya/labels.csv",'w+',newline = '')
writer = csv.writer(fp)
for i in labels:
    writer.writerow([i])
fp.close()

print("\nMobileNetV2 : ", end="")
for i in p:
    print(i, end=" ")
print()


print("For MobileNetV2 : ")
metrics(labels, p, list(map(str, range(1, 9))), os.listdir("/home/cmater/Desktop/Akash_MCSE/Surya/breakhis-dataset-expanded"))
plot_roc(labels, p)

avg_acc_list = []
avg_precision_list = []
avg_recall_list = []
avg_f1_list = []

acc_fold = accuracy_score(labels, p)
avg_acc_list.append(acc_fold)
precision_fold = precision_score(labels, p, average='macro')
avg_precision_list.append(precision_fold)
recall_fold = recall_score(labels, p, average='macro')
avg_recall_list.append(recall_fold)
f1_fold  = f1_score(labels, p, average='macro')
avg_f1_list.append(f1_fold)

print('Accuracy[{:.4f}] Precision[{:.4f}] Recall[{:.4f}] F1[{:.4f}] ]'.format(acc_fold, precision_fold, recall_fold, f1_fold ))
print('________________________________________________________________')

avg_acc = np.asarray(avg_acc_list)
avg_pre = np.asarray(avg_precision_list)
avg_recall = np.asarray(avg_recall_list)
avg_f1 = np.asarray(avg_f1_list)
print("\n")
print('Overall Accuracy[{:.4f}] Overall Precision[{:.4f}] Overall Recall[{:.4f}] Overall F1[{:.4f}]'.format(np.mean(avg_acc), np.mean(avg_pre), np.mean(avg_recall), np.mean(avg_f1)))
# Out:
# MobileNetV2 : 5 7 2 5 1 5 2 2 1 5 1 1 3 5 7 6 1 6 1 1 3 1 4 2 4 5 1 4 1 1 1 1 2 1 6 5 1 6 5 6 1 2 1 7 4 5 1 3 2 1 1 4 0 1 3 3 1 2 1 0 1 7 2 1 2 3 1 1 1 4 3 1 1 5 5 1 1 1 1 4 1 2 7 1 1 3 0 1 6 4 4 1 6 0 1 3 1 6 7 6 5 1 2 2 1 2 1 1 5 1 2 2 2 1 1 1 3 7 1 6 1 7 2 2 0 1 0 1 7 5 5 1 1 1 5 1 1 2 6 5 5 3 1 6 2 5 3 2 2 2 1 1 1 5 1 2 4 1 1 1 4 1 4 1 5 2 6 3 0 3 1 0 1 3 4 1 1 2 1 1 5 3 6 1 1 5 2 4 1 1 1 7 1 0 1 1 2 1 1 7 1 2 5 1 1 4 4 1 7 2 6 1 3 2 1 4 4 1 1 1 1 3 6 1 6 1 3 6 4 2 4 1 1 4 2 4 3 4 1 1 3 4 2 6 2 1 0 4 1 5 4 2 1 1 0 1 1 1 4 4 1 4 4 2 1 1 2 7 3 5 1 1 1 1 1 1 1 2 2 1 2 1 1 4 2 7 6 2 5 1 2 1 0 1 1 1 1 7 2 2 2 1 3 4 7 1 1 5 2 4 1 1 1 1 7 1 1 1 2 1 0 2 0 1 4 1 2 1 1 1 2 1 1 1 3 3 3 1 1 1 1 2 2 7 2 1 7 1 1 4 0 0 3 4 5 2 1 4 2 2 1 1 1 1 2 1 1 0 3 0 1 4 1 1 1 7 1 4 0 7 1 7 1 1 7 5 7 7 1 1 2 3 0 7 6 3 2 1 2 4 6 2 2 1 3 3 1 1 7 2 3 1 1 3 5 6 3 3 1 1 1 5 2 1 1 1 1 5 1 1 6 3 4 1 5 1 3 2 2 1 1 0 7 3 1 7 5 5 2 0 3 2 5 2 2 1 2 2 0 1 6 1 6 5 4 6 2 2 2 1 3 2 4 1 1 1 1 1 2 1 2 1 2 1 7 7 1 2 1 5 4 3 6 3 1 1 1 4 1 1 2 1 3 1 1 2 4 4 1 6 3 5 4 0 3 4 1 3 2 1 1 2 1 1 1 4 1 1 4 6 0 1 3 2 3 1 6 7 1 2 0 7 5 5 1 1 3 1 1 2 1 1 1 4 3 1 6 2 3 1 1 1 5 3 1 2 3 4 5 1 1 5 2 0 1 1 3 5 5 1 2 2 3 1 1 1 0 1 2 1 1 1 6 1 1 7 1 4 2 2 1 1 1 3 7 5 1 1 1 1 5 6 1 1 1 1 1 3 3 1 4 3 2 3 3 3 2 1 7 1 0 1 5 0 5 1 6 1 1 1 4 1 1 6 1 1 4 1 1 1 1 2 1 1 1 6 1 1 1 7 7 2 2 1 1 4 7 6 0 1 7 1 1 1 4 7 2 2 5 1 6 5 1 1 2 0 1 2 1 2 1 3 1 4 2 1 1 2 5 7 6 4 1 1 4 0 2 1 1 3 1 1 2 1 1 5 4 7 7 7 4 0 1 3 1 2 1 1 3 3 0 1 3 6 2 1 5 7 1 3 4 1 4 1 1 1 1 1 7 1 1 5 1 3 5 4 2 3 1 3 0 1 1 7 1 4 1 0 6 1 1 4 3 0 1 1 7 1 1 2 0 0 7 1 3 4 2 1 7 6 1 6 1 1 3 4 1 4 7 5 1 1 1 1 1 1 4 1 6 6 1 0 4 5 4 4 1 2 1 2 4 5 1 4 1 1 1 2 2 6 1 3 1 1 1 2 2 1 1 6 4 1 1 4 1 2 1 1 6 3 5 7 1 4 3 3 3 1 5 2 4 4 1 6 2 7 1 0 1 7 1 3 1 6 1 1 1 5 1 7 3 0 2 1 1 1 7 1 4 1 6 2 2 1 6 1 2 4 4 1 4 6 4 1 1 1 3 1 1 1 1 1 5 4 0 2 1 1 1 1 4 1 5 1 2 5 7 5 2 1 5 1 1 0 4 0 5 4 7 3 1 5 4 4 6 1 1 0 6 1 1 3 1 1 1 2 5 1 3 1 4 4 2 7 2 1 1 4 1 2 1 2 6 6 1 3 1 0 2 3 1 1 1 2 5 0 6 1 3 1 6 1 1 1 0 1 5 4 7 1 4 1 1 5 1 2 2 1 1 1 4 5 1 5 7 1 1 1 2 1 0 1 1 1 4 7 1 5 6 6 3 5 3 7 7 1 4 2 1 1 4 5 6 6 2 6 0 1 1 0 1 5 5 4 1 1 2 1 4 5 4 3 5 2 0 2 1 1 4 7 2 7 1 7 3 0 4 1 4 0 2 1 1 4 2 3 1 1 1 5 1 1 4 1 6 7 7 1 5 2 7 1 7 4 1 1 1 1 1 7 4 1 0 0 1 1 1 5 1 3 7 3 6 1 0 1 6 2 6 1 4 5 4 3 1 2 7 0 1 7 1 1 1 6 0 1 1 4 6 4 2 7 7 7 6 1 5 5 1 3 5 1 1 4 1 3 1 1 1 3 1 3 1 1 4 3 3 1 1 4 0 0 3 1 5 2 5 5 7 5 1 4 3 4 1 6 1 6 4 3 3 1 6 2 1 2 2 2 0 5 1 2 1 4 1 2 1 1 3 1 0 2 1 3 1 2 1 4 1 2 5 0 1 1 1 4 5 4 1 1 3 1 2 5 1 1 1 1 7 1 3 3 2 1 5 1 1 1 2 7 0 2 1 4 7 7 1 4 7 1 0 1 4 5 6 4 1 5 7 3 2 7 6 4 4 4 5 1 4 4 1 1 2 1 1 0 1 1 1 4 1 2 7 1 1 3 1 4 1 2 1 1 0 1 1 1 1 1 1 2 6 7 1 1 1 2 1 1 1 2 1 5 1 7 5 1 2 5 2 4 5 6 1 1 1 2 1 7 5 2 3 4 3 7 4 2 7 1 4 2 2 4 1 5 1 5 4 0 1 1 1 1 2 1 4 0 1 3 1 1 1 4 1 5 1 1 1 1 1 3 0 5 1 1 1 1 3 1 2 1 1 0 1 0 1 4 1 4 1 4 6 7 1 1 1 6 2 2 1 1 3 6 6 0 4 2 7 2 1 4 1 1 0 6 0 2 4 3 2 2 1 1 1 1 4 5 0 7 4 5 1 2 5 7 1 1 3 1 2 4 3 4 0 1 0 1 2 2 1 4 2 1 3 1 2 1 6 6 1 3 2 1 1 1 1 2 2 3 5 1 1 6 4 1 4 3 1 1 7 5 2 7 3 1 6 2 5 3 4 2 1 5 1 3 1 5 1 2 2 1 1 4 0 1 2 4 2 1 1 1 2 1 3 1 4 7 1 2 3 5 2 1 5 1 1 1 6 2 2 7 0 5 4 1 4 1 0 0 5 2 1 4 1 3 0 1 7 0 4 1 4 2 7 4 1 5 1 4 3 5 7 4 1 0
# For MobileNetV2 :
# Classification Report:
# Labels :  (1584,)
# Predictions :  (1584,)
#               precision    recall  f1-score   support
#
#            1     0.9886    1.0000    0.9943        87
#            2     0.9924    0.9673    0.9797       673
#            3     0.9953    1.0000    0.9977       214
#            4     0.9037    0.9606    0.9313       127
#            5     0.9942    0.9827    0.9884       173
#            6     0.9365    1.0000    0.9672       118
#            7     1.0000    1.0000    1.0000        89
#            8     0.9904    1.0000    0.9952       103
#
#     accuracy                         0.9811      1584
#    macro avg     0.9751    0.9888    0.9817      1584
# weighted avg     0.9818    0.9811    0.9812      1584
#
# Confusion matrix:
# [[ 87   0   0   0   0   0   0   0]
#  [  0 651   1  12   1   8   0   0]
#  [  0   0 214   0   0   0   0   0]
#  [  0   5   0 122   0   0   0   0]
#  [  1   0   0   1 170   0   0   1]
#  [  0   0   0   0   0 118   0   0]
#  [  0   0   0   0   0   0  89   0]
#  [  0   0   0   0   0   0   0 103]]
# Classwise Accuracy :[1.         0.96731055 1.         0.96062992 0.98265896 1.
#  1.         1.        ]
#
# Balanced Accuracy Score:  0.9888249288218165
# Accuracy[0.9811] Precision[0.9751] Recall[0.9888] F1[0.9817] ]
# ________________________________________________________________
#
#
# Overall Accuracy[0.9811] Overall Precision[0.9751] Overall Recall[0.9888] Overall F1[0.9817]
